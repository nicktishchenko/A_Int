# %% [markdown]
# # Universal Serial Number and Event Extractor
#
# This notebook scans CSV, Excel, PDF, PST, and image files in the `data` directory, extracts serial numbers, events, names, addresses, and outputs a CSV report.

# %%
# Cell 1: Imports and setup
import os
import re
import subprocess
import shutil

import pandas as pd

from typing import Dict, List, Any, Optional
from collections import defaultdict
import datetime
from datetime import datetime, date

import pytesseract
from PIL import Image
import spacy
import dateparser
import pdfplumber
import glob

import warnings

# nlp = spacy.load('en_core_web_trf')  # Transformer-based English NER
nlp = spacy.load("en_core_web_sm")

# %%
# Cell 2: Dataset Template Classes for Standardized Event Processing
# This cell defines the standardized structure for all extracted serial number events


class EventRecord:
    """
    Standardized event record structure for serial number events.
    """

    def __init__(self):
        self.serial_number: str = ""
        self.event_type: str = (
            ""  # Any event type (e.g., "Acquisition", "Disposition", "Transfer", "Return", etc.)
        )
        self.event_date: str = ""  # Date in YYYY-MM-DD format or original format
        self.associated_name: str = ""
        self.associated_address: str = ""
        self.source_file: str = ""
        self.file_created: str = ""  # File creation date in YYYY-MM-DD format
        self.file_modified: str = ""  # File modification date in YYYY-MM-DD format

    def to_dict(self) -> Dict[str, str]:
        """Convert record to dictionary format."""
        return {
            "serial_number": self.serial_number,
            "event_type": self.event_type,
            "event_date": self.event_date,
            "associated_name": self.associated_name,
            "associated_address": self.associated_address,
            "source_file": self.source_file,
            "file_created": self.file_created,
            "file_modified": self.file_modified,
        }


class DatasetTemplate:
    """
    Template class for managing the standardized dataset structure.
    """

    # Column definitions with expected data types
    COLUMN_SCHEMA = {
        "serial_number": "string",
        "event_type": "string",
        "event_date": "string",
        "associated_name": "string",
        "associated_address": "string",
        "source_file": "string",
        "file_created": "string",
        "file_modified": "string",
    }

    # Required columns (all are required for consistency)
    REQUIRED_COLUMNS = list(COLUMN_SCHEMA.keys())

    @staticmethod
    def create_empty_dataframe() -> pd.DataFrame:
        """Create an empty DataFrame with the correct column structure."""
        return pd.DataFrame(columns=DatasetTemplate.REQUIRED_COLUMNS)

    @staticmethod
    def validate_record(record: Dict[str, Any]) -> bool:
        """Validate that a record contains all required fields."""
        # Check all required columns are present
        for col in DatasetTemplate.REQUIRED_COLUMNS:
            if col not in record:
                return False

        # Validate that event_type is not empty (but accept any non-empty string)
        if not record.get("event_type") or str(record.get("event_type")).strip() == "":
            return False

        return True

    @staticmethod
    def create_record(
        serial_number: str,
        event_type: str,
        event_date: str = "",
        associated_name: str = "",
        associated_address: str = "",
        source_file: str = "",
        file_created: str = "",
        file_modified: str = "",
    ) -> EventRecord:
        """Create a standardized event record."""
        record = EventRecord()
        record.serial_number = str(serial_number).strip()
        record.event_type = str(event_type).strip()  # Accept any event type
        record.event_date = str(event_date).strip()
        record.associated_name = str(associated_name).strip()
        record.associated_address = str(associated_address).strip()
        record.source_file = str(source_file).strip()
        record.file_created = str(file_created).strip()
        record.file_modified = str(file_modified).strip()

        return record

    @staticmethod
    def get_file_metadata(filepath: str) -> tuple:
        """Extract file creation and modification dates."""
        try:
            stat = os.stat(filepath)
            created = datetime.fromtimestamp(stat.st_ctime)
            modified = datetime.fromtimestamp(stat.st_mtime)

            # Ensure created date is not later than modified date
            if modified < created:
                created, modified = modified, created

            return created.date().strftime("%Y-%m-%d"), modified.date().strftime(
                "%Y-%m-%d"
            )
        except Exception:
            return "", ""

    @staticmethod
    def combine_address_fields(*address_parts) -> str:
        """Combine multiple address components into a single address string."""
        # Filter out empty/null values and strip whitespace
        clean_parts = []
        for part in address_parts:
            if part and str(part).strip() and str(part).strip().lower() != "nan":
                clean_parts.append(str(part).strip())

        # Join with commas and clean up formatting
        address = ", ".join(clean_parts)
        return address.replace(" ,", "").strip(", ")

    @staticmethod
    def standardize_dataframe(df: pd.DataFrame) -> pd.DataFrame:
        """Standardize a DataFrame to match the template structure."""
        # Ensure all required columns exist
        for col in DatasetTemplate.REQUIRED_COLUMNS:
            if col not in df.columns:
                df[col] = ""

        # Select only the required columns in the correct order
        df = df[DatasetTemplate.REQUIRED_COLUMNS].copy()

        # Convert all columns to string type and strip whitespace
        for col in df.columns:
            df[col] = df[col].astype(str).str.strip()

        # Remove exact duplicates
        df = df.drop_duplicates()

        return df

    @staticmethod
    def save_to_csv(df: pd.DataFrame, filepath: str) -> None:
        """Save DataFrame to CSV with standardized formatting."""
        # Ensure directory exists
        os.makedirs(os.path.dirname(filepath), exist_ok=True)

        # Standardize before saving
        standardized_df = DatasetTemplate.standardize_dataframe(df)

        # Save to CSV
        standardized_df.to_csv(filepath, index=False)
        print(f"Saved {len(standardized_df)} records to {filepath}")

    @staticmethod
    def get_unique_event_types(df: pd.DataFrame) -> List[str]:
        """Get all unique event types found in the dataset."""
        if "event_type" in df.columns:
            return sorted(df["event_type"].dropna().unique().tolist())
        return []


print("Dataset template classes loaded successfully!")
print(f"Required columns: {DatasetTemplate.REQUIRED_COLUMNS}")
print("Event types: Dynamic - any non-empty string accepted")
# Out:
# Dataset template classes loaded successfully!
# Required columns: ['serial_number', 'event_type', 'event_date', 'associated_name', 'associated_address', 'source_file', 'file_created', 'file_modified']
# Event types: Dynamic - any non-empty string accepted

# %%
# Cell 3: Create reports directory and Serial Number Extractor

if not os.path.exists("reports"):
    os.makedirs("reports")
    print("Created 'reports' directory.")


# Serial Number Extractor
class SerialNumberExtractor:
    def __init__(self):
        self.patterns = [
            r"\b[A-Z0-9]{6,12}US\b",
            r"\b[A-Z]{4}[0-9]{3}\b",
            r"\b[A-Z]{4}[0-9]{3,4}\b",
            r"\b[A-Z]{3}[0-9]{3,4}\b",
            r"\b[0-9][A-Z]{3}[0-9]{3}\b",
            r"\b[A-Z]{2,4}[0-9]{4,8}\b",
            r"\b[0-9]{4,12}[A-Z]{1,4}\b",
            r"\b[A-Z][0-9]{4,8}[A-Z]\b",
            r"\b[0-9]{6,12}\b",
            r"\b[A-Z0-9]{2,4}[-_][A-Z0-9]{2,8}\b",
            r"\b[A-Z0-9]{3,8}[-_][0-9]{2,6}\b",
        ]
        self.compiled_patterns = [re.compile(pattern) for pattern in self.patterns]
        self.exclude_patterns = [
            r"\b[0-9]{4}[/-][0-9]{1,2}[/-][0-9]{1,2}\b",
            r"\b[0-9]{1,2}[/-][0-9]{1,2}[/-][0-9]{4}\b",
            r"\bZIP\b",
            r"\bFFL\b",
            r"\bATF\b",
            r"\bPDF\b",
            r"\b(PAGE|FORM|SECTION|ITEM|LINE)\b",
        ]
        self.exclude_compiled = [
            re.compile(pattern, re.IGNORECASE) for pattern in self.exclude_patterns
        ]

    def extract(self, text):
        serials = set()
        for pattern in self.compiled_patterns:
            for match in pattern.findall(text):
                if not any(excl.search(match) for excl in self.exclude_compiled):
                    serials.add(match)
        return list(serials)

# %%
# Cell 4: File Discovery and Analysis
# This cell scans the data directory to identify all available source files


def discover_source_files(data_dir="data"):
    """
    Discover and analyze all source files in the data directory.
    """
    if not os.path.exists(data_dir):
        print(f"Data directory '{data_dir}' not found!")
        return

    print(f"Scanning directory: {data_dir}")
    print("=" * 60)

    # File extensions to look for
    target_extensions = {
        "csv": "CSV Files",
        "xlsx": "Excel Files (xlsx)",
        "xls": "Excel Files (xls)",
        "pdf": "PDF Files",
        "pst": "PST Files",
        "jpg": "Image Files (jpg)",
        "jpeg": "Image Files (jpeg)",
        "png": "Image Files (png)",
        "tiff": "Image Files (tiff)",
        "tif": "Image Files (tif)",
    }

    # Discover files
    file_stats = defaultdict(list)
    total_files = 0

    for ext, description in target_extensions.items():
        pattern = os.path.join(data_dir, "**", f"*.{ext}")
        files = glob.glob(pattern, recursive=True)

        if files:
            file_stats[description] = files
            total_files += len(files)

    # Display results
    print(f"Total files found: {total_files}")
    print()

    if total_files == 0:
        print("No supported files found in the data directory!")
        print(
            "Supported formats: CSV, Excel (xlsx/xls), PDF, PST, Images (jpg/jpeg/png/tiff/tif)"
        )
        return

    # Show breakdown by file type
    for file_type, files in file_stats.items():
        print(f"{file_type}: {len(files)} files")
        for file_path in sorted(files):
            # Get file size
            try:
                size = os.path.getsize(file_path)
                size_str = format_file_size(size)
                rel_path = os.path.relpath(file_path, data_dir)
                print(f"  {rel_path} ({size_str})")
            except Exception as e:
                rel_path = os.path.relpath(file_path, data_dir)
                print(f"  {rel_path} (size unknown)")
        print()

    # Summary statistics
    print("SUMMARY:")
    print("-" * 30)
    for file_type, files in sorted(file_stats.items()):
        print(f"{file_type}: {len(files)}")

    return file_stats


def format_file_size(size_bytes):
    """Convert bytes to human readable format."""
    if size_bytes == 0:
        return "0 B"

    size_names = ["B", "KB", "MB", "GB"]
    i = 0
    while size_bytes >= 1024 and i < len(size_names) - 1:
        size_bytes /= 1024.0
        i += 1

    return f"{size_bytes:.1f} {size_names[i]}"


# Run the discovery
discovered_files = discover_source_files()

# Store results for later use
if discovered_files:
    print("\nFile discovery complete! Results stored in 'discovered_files' variable.")
    print("Ready to proceed with processing these files.")
else:
    print("\nNo files found. Please check your data directory.")
# Out:
# Scanning directory: data
# ============================================================
# Total files found: 52
#
# CSV Files: 1 files
#   AUS Weapons List.csv (3.2 MB)
#
# Excel Files (xlsx): 20 files
#   2021 Central Inventory Form.xlsx (251.0 KB)
#   2022 Weapon Inventory Form.xlsx (9.0 MB)
#   4-29-2021 IN-SAFE 4144 Weapons Inventory.xlsx (24.2 KB)
#   ABSS FFL A&D Log 06_19_2019 with location.xlsx (556.4 KB)
#   AUS FFL Workbook 06_02_22 JCG.xlsx (1.2 MB)
#   AUS-USSA Firearm Inventory.xlsx (508.6 KB)
#   AUS-USSA Firearm Workbook.xlsx (466.7 KB)
#   CE Region Inv Report7_19_23.xlsx (56.9 KB)
#   Central AUS Inventory.xlsx (144.8 KB)
#   Copy of 20250320 - Firearm audit worksheet.xlsx (614.7 KB)
#   Dallas Branch 600+.xlsx (22.5 KB)
#   Dallas Workbook.xlsx (645.9 KB)
#   Expected FA.xlsx (161.8 KB)
#   FFL Workbook 6_3_20 to ND.xlsx (826.9 KB)
#   Master Certification List MAC45.xlsx (70.5 KB)
#   Murray Weapons (2).xlsx (82.4 KB)
#   New AUS FFL A&D Log 07_03_2019 with location.xlsx (266.0 KB)
#   Unassigned Orchid Fireams as of 1300CST 03172025.xlsx (131.6 KB)
#   Weapons Database - Area 16.xlsx (34.0 KB)
#   Weapons comparison v 1.xlsx (8.5 MB)
#
# Excel Files (xls): 5 files
#   032415 443 pm Mike File.xls (90.0 KB)
#   CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls (106.0 KB)
#   Certified Parts Order form ALLIED UNIVERSAL 1.9.2023.xls (289.5 KB)
#   P3 list for AU - company owned.xls (294.0 KB)
#   ussa firearms 1_15_2019 JCG.xls (304.5 KB)
#
# PDF Files: 20 files
#   06.Layna Payne Firearm Inspection 2025.pdf (2.3 MB)
#   082417-082517 Colt M4's.pdf (2.7 MB)
#   09085287.pdf (14.7 KB)
#   3310 BFMU971 bp.pdf (1.1 MB)
#   3310 BFMU971 fp.pdf (1.1 MB)
#   AUS AAR Friday May 21st.pdf (148.8 KB)
#   BHKH089.pdf (293.7 KB)
#   BSPB295.pdf (1.3 MB)
#   C777274 - NYPD Complaint Report.pdf (249.9 KB)
#   Equipment Transfer Report 112020_11202020095038.pdf (1.3 MB)
#   Frederuck, Darece Pistol License Front and Back.pdf (235.1 KB)
#   Invoice_1961083.pdf (131.4 KB)
#   SKM_C754e17121413380.pdf (3.9 MB)
#   SM Hunter - Armed Guard List - Google Docs.pdf (49.2 KB)
#   SN Buy Backs 10-18.pdf (82.9 KB)
#   Trace BEGY046.pdf (322.0 KB)
#   Training Participation Registration Request Kwame.pdf (833.9 KB)
#   UPDATED FIREARM TRACKER.pdf (89.5 KB)
#   Untitled document.pdf (26.0 KB)
#   XSV989-1.pdf (345.6 KB)
#
# PST Files: 1 files
#   Export_20250626141845886_Part_1.pst (813.8 MB)
#
# Image Files (jpg): 4 files
#   ABNC981.jpg (2.7 MB)
#   IMG_1357.jpg (2.3 MB)
#   IMG_20220104_133627.jpg (340.3 KB)
#   MUF408.jpg (129.3 KB)
#
# Image Files (jpeg): 1 files
#   XCF070.jpeg (654.1 KB)
#
# SUMMARY:
# ------------------------------
# CSV Files: 1
# Excel Files (xls): 5
# Excel Files (xlsx): 20
# Image Files (jpeg): 1
# Image Files (jpg): 4
# PDF Files: 20
# PST Files: 1
#
# File discovery complete! Results stored in 'discovered_files' variable.
# Ready to proceed with processing these files.

# %%
# Cell 5: PST Attachment Discovery and EML Processing
# This cell discovers all PST attachments and processes EML files to extract content and embedded attachments

import email
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import mimetypes


def discover_and_process_pst_attachments(discovered_files, temp_dir="temp_attachments"):
    """
    Discover all PST attachments and process EML files for content and embedded attachments.
    """
    if "PST Files" not in discovered_files:
        print("No PST files found.")
        return discovered_files, []

    print("DISCOVERING AND PROCESSING PST ATTACHMENTS")
    print("=" * 60)

    # Use the readpst command we know works
    readpst_command = "/opt/homebrew/bin/readpst"

    all_attachments = []
    email_content = []
    extracted_attachments = []

    for pst_path in discovered_files["PST Files"]:
        print(f"\nAnalyzing PST: {os.path.basename(pst_path)}")

        # Create temporary extraction directory
        readpst_temp = os.path.join(temp_dir, "discovery_temp")
        if os.path.exists(readpst_temp):
            shutil.rmtree(readpst_temp)
        os.makedirs(readpst_temp)

        try:
            # Extract everything from PST
            cmd = [readpst_command, "-e", "-o", readpst_temp, pst_path]
            result = subprocess.run(cmd, capture_output=True, text=True, timeout=300)

            if result.returncode != 0:
                print(f"Error extracting PST: {result.stderr}")
                continue

            # Scan all extracted files
            pst_attachments = []
            eml_files = []

            for root, dirs, files in os.walk(readpst_temp):
                for file in files:
                    file_path = os.path.join(root, file)
                    file_size = os.path.getsize(file_path)

                    # Get file extension
                    if "." in file:
                        ext = file.split(".")[-1].lower()
                    else:
                        ext = "no_extension"

                    attachment_info = {
                        "filename": file,
                        "extension": ext,
                        "size_bytes": file_size,
                        "size_readable": format_file_size(file_size),
                        "path": file_path,
                        "pst_source": os.path.basename(pst_path),
                    }
                    pst_attachments.append(attachment_info)
                    all_attachments.append(attachment_info)

                    # Collect EML files for processing
                    if ext == "eml":
                        eml_files.append(file_path)

            # Display attachments from this PST
            if pst_attachments:
                print(f"Found {len(pst_attachments)} files:")

                # Group by extension
                ext_groups = {}
                for att in pst_attachments:
                    ext = att["extension"]
                    if ext not in ext_groups:
                        ext_groups[ext] = []
                    ext_groups[ext].append(att)

                for ext, files in sorted(ext_groups.items()):
                    print(f"  .{ext} files: {len(files)}")

            # Process EML files from this PST
            if eml_files:
                print(
                    f"\nProcessing {len(eml_files)} EML files for embedded attachments..."
                )

                for eml_path in eml_files:
                    try:
                        # Parse EML file
                        with open(eml_path, "rb") as f:
                            msg = email.message_from_bytes(f.read())

                        # Extract email metadata
                        subject = msg.get("Subject", "No Subject")
                        sender = msg.get("From", "Unknown Sender")
                        recipient = msg.get("To", "Unknown Recipient")
                        date = msg.get("Date", "Unknown Date")

                        # Extract email body text
                        body_text = ""
                        if msg.is_multipart():
                            for part in msg.walk():
                                if part.get_content_type() == "text/plain":
                                    try:
                                        body_text += part.get_payload(
                                            decode=True
                                        ).decode("utf-8", errors="ignore")
                                    except:
                                        pass
                        else:
                            if msg.get_content_type() == "text/plain":
                                try:
                                    body_text = msg.get_payload(decode=True).decode(
                                        "utf-8", errors="ignore"
                                    )
                                except:
                                    pass

                        # Store email content for serial number extraction
                        if body_text.strip():
                            email_content.append(
                                {
                                    "filename": os.path.basename(eml_path),
                                    "subject": subject,
                                    "sender": sender,
                                    "recipient": recipient,
                                    "date": date,
                                    "body": body_text,
                                    "source_file": eml_path,
                                    "pst_source": os.path.basename(pst_path),
                                }
                            )

                        # Extract attachments from email
                        if msg.is_multipart():
                            for part in msg.walk():
                                # Skip text parts
                                if part.get_content_maintype() == "multipart":
                                    continue
                                if part.get("Content-Disposition") is None:
                                    continue

                                # Get attachment filename
                                filename = part.get_filename()
                                if filename:
                                    # Decode filename if needed
                                    if filename.startswith("=?"):
                                        try:
                                            filename = email.header.decode_header(
                                                filename
                                            )[0][0]
                                            if isinstance(filename, bytes):
                                                filename = filename.decode(
                                                    "utf-8", errors="ignore"
                                                )
                                        except:
                                            pass

                                    # Save attachment
                                    timestamp = datetime.now().strftime(
                                        "%Y%m%d_%H%M%S_%f"
                                    )
                                    safe_filename = f"{timestamp}_{filename}"
                                    attachment_path = os.path.join(
                                        temp_dir, safe_filename
                                    )

                                    try:
                                        with open(attachment_path, "wb") as f:
                                            f.write(part.get_payload(decode=True))

                                        extracted_attachments.append(
                                            {
                                                "original_name": filename,
                                                "saved_path": attachment_path,
                                                "extension": (
                                                    filename.split(".")[-1].lower()
                                                    if "." in filename
                                                    else "no_ext"
                                                ),
                                                "source_email": os.path.basename(
                                                    eml_path
                                                ),
                                                "pst_source": os.path.basename(
                                                    pst_path
                                                ),
                                            }
                                        )
                                    except Exception as e:
                                        print(
                                            f"    Error saving attachment {filename}: {str(e)}"
                                        )

                    except Exception as e:
                        print(
                            f"  Error processing EML {os.path.basename(eml_path)}: {str(e)}"
                        )
                        continue

            # Clean up temp directory
            shutil.rmtree(readpst_temp)

        except Exception as e:
            print(f"Error processing {pst_path}: {str(e)}")
            continue

    # Summary of all discoveries
    print(f"\n" + "=" * 60)
    print(f"PST PROCESSING SUMMARY")
    print("=" * 60)

    if all_attachments:
        # Group all attachments by extension
        ext_summary = {}
        for att in all_attachments:
            ext = att["extension"]
            if ext not in ext_summary:
                ext_summary[ext] = {"count": 0, "total_size": 0}
            ext_summary[ext]["count"] += 1
            ext_summary[ext]["total_size"] += att["size_bytes"]

        print(f"Found {len(all_attachments)} total files in PST:")
        for ext, info in sorted(ext_summary.items()):
            total_size_readable = format_file_size(info["total_size"])
            print(f"  .{ext}: {info['count']} files ({total_size_readable})")

    if email_content:
        print(f"\nProcessed {len(email_content)} emails with text content")

    if extracted_attachments:
        print(
            f"Extracted {len(extracted_attachments)} embedded attachments from emails"
        )

        # Group extracted attachments by type
        att_by_ext = {}
        for att in extracted_attachments:
            ext = att["extension"]
            if ext not in att_by_ext:
                att_by_ext[ext] = 0
            att_by_ext[ext] += 1

        print("\nExtracted attachment types:")
        for ext, count in sorted(att_by_ext.items()):
            print(f"  .{ext}: {count} files")

        # Add extracted attachments to discovered_files
        attachment_mapping = {
            "csv": "CSV Files",
            "xlsx": "Excel Files (xlsx)",
            "xls": "Excel Files (xls)",
            "pdf": "PDF Files",
            "jpg": "Image Files (jpg)",
            "jpeg": "Image Files (jpeg)",
            "png": "Image Files (png)",
            "tiff": "Image Files (tiff)",
            "tif": "Image Files (tif)",
            "txt": "Text Files",
        }

        added_files = 0
        for att in extracted_attachments:
            ext = att["extension"]
            if ext in attachment_mapping:
                file_type = attachment_mapping[ext]
                if file_type not in discovered_files:
                    discovered_files[file_type] = []
                discovered_files[file_type].append(att["saved_path"])
                added_files += 1

        if added_files > 0:
            print(
                f"\nAdded {added_files} extracted attachments to file inventory for processing"
            )

    return discovered_files, email_content


def format_file_size(size_bytes):
    """Convert bytes to human readable format."""
    if size_bytes == 0:
        return "0 B"

    size_names = ["B", "KB", "MB", "GB"]
    i = 0
    while size_bytes >= 1024 and i < len(size_names) - 1:
        size_bytes /= 1024.0
        i += 1

    return f"{size_bytes:.1f} {size_names[i]}"


# Run PST discovery and processing
if "discovered_files" in globals() and discovered_files:
    discovered_files, email_texts = discover_and_process_pst_attachments(
        discovered_files
    )

    # Display updated file counts
    print("\nUpdated file inventory after PST processing:")
    print("-" * 50)
    total_files = 0
    for file_type, files in sorted(discovered_files.items()):
        print(f"{file_type}: {len(files)}")
        total_files += len(files)
    print(f"Total files: {total_files}")

    if email_texts:
        print(
            f"\nEmail content available for text-based serial number extraction: {len(email_texts)} emails"
        )
else:
    print("No discovered_files found. Run file discovery first.")
# Out:
# DISCOVERING AND PROCESSING PST ATTACHMENTS
# ============================================================
#
# Analyzing PST: Export_20250626141845886_Part_1.pst
# Found 343 files:
#   .eml files: 343
#
# Processing 343 EML files for embedded attachments...
#     Error saving attachment details.txt: a bytes-like object is required, not 'NoneType'
#
# ============================================================
# PST PROCESSING SUMMARY
# ============================================================
# Found 343 total files in PST:
#   .eml: 343 files (1008.0 MB)
#
# Processed 340 emails with text content
# Extracted 1315 embedded attachments from emails
#
# Extracted attachment types:
#   .csv: 12 files
#   .doc: 5 files
#   .docx: 13 files
#   .htm: 7 files
#   .jpeg: 2 files
#   .jpg: 97 files
#   .pdf: 193 files
#   .png: 630 files
#   .rtf: 1 files
#   .xls: 28 files
#   .xlsx: 325 files
#   .zip: 2 files
#
# Added 1287 extracted attachments to file inventory for processing
#
# Updated file inventory after PST processing:
# --------------------------------------------------
# CSV Files: 13
# Excel Files (xls): 33
# Excel Files (xlsx): 345
# Image Files (jpeg): 3
# Image Files (jpg): 101
# Image Files (png): 630
# PDF Files: 213
# PST Files: 1
# Total files: 1339
#
# Email content available for text-based serial number extraction: 340 emails

# %%
# Cell 6: CSV File Processing with DatasetTemplate
# This cell processes all CSV files using the standardized dataset template

import tempfile
import os


def preprocess_csv_for_alignment(csv_path):
    """
    Preprocess CSV file to fix misaligned rows caused by names with Jr/Sr/etc.
    """
    # Read the file as text lines first
    with open(csv_path, "r", encoding="utf-8", errors="ignore") as file:
        lines = file.readlines()

    if not lines:
        return csv_path

    # Get the expected number of columns from the header
    header_cols = lines[0].count(",") + 1

    # Process each line to fix misalignment
    fixed_lines = [lines[0]]  # Keep header as is

    for i, line in enumerate(lines[1:], 1):
        # Count columns in this line
        line_cols = line.count(",") + 1

        if line_cols == header_cols:
            # Line is properly aligned, keep as is
            fixed_lines.append(line)
        elif line_cols > header_cols:
            # Line has extra columns, likely due to split names
            # Try to merge the extra columns back into the appropriate fields
            parts = line.strip().split(",")

            # Look for common name suffixes that might be split
            for j in range(len(parts) - 1, 0, -1):
                if parts[j].strip().lower() in ["jr", "sr", "ii", "iii", "iv"]:
                    # Merge this with the previous part
                    parts[j - 1] = parts[j - 1].strip() + " " + parts[j].strip()
                    parts.pop(j)
                    break

            # If we still have too many columns, join the extras to the last meaningful field
            while len(parts) > header_cols and len(parts) > 1:
                # Join extra columns to the last field that might contain names
                parts[-2] = parts[-2].strip() + " " + parts[-1].strip()
                parts.pop()

            # Reconstruct the line
            fixed_line = ",".join(parts) + "\n"
            fixed_lines.append(fixed_line)
        else:
            # Line has fewer columns, pad with empty fields
            parts = line.strip().split(",")
            while len(parts) < header_cols:
                parts.append("")
            fixed_line = ",".join(parts) + "\n"
            fixed_lines.append(fixed_line)

    # Write fixed content to a temporary file
    temp_file = tempfile.NamedTemporaryFile(
        mode="w", delete=False, suffix=".csv", encoding="utf-8"
    )
    temp_file.writelines(fixed_lines)
    temp_file.close()

    return temp_file.name


def process_csv_files(discovered_files):
    """
    Process all CSV files using the standardized DatasetTemplate.
    """
    if "CSV Files" not in discovered_files:
        print("No CSV files found for processing.")
        return []

    print("PROCESSING CSV FILES")
    print("=" * 50)

    csv_files = discovered_files["CSV Files"]
    print(f"Found {len(csv_files)} CSV files to process")

    all_csv_records = []
    processed_files = 0
    skipped_files = 0

    for csv_path in csv_files:
        print(f"\nProcessing: {os.path.basename(csv_path)}")

        try:
            # Preprocess to fix alignment issues
            fixed_csv_path = preprocess_csv_for_alignment(csv_path)

            # Read the fixed CSV file
            df = pd.read_csv(fixed_csv_path, dtype=str, encoding="utf-8")
            print(f"  Loaded {len(df)} rows, {len(df.columns)} columns")

            # Clean up temporary file
            if fixed_csv_path != csv_path:
                os.unlink(fixed_csv_path)

        except Exception as e:
            print(f"  Error reading file: {e}")
            skipped_files += 1
            continue

        # Check for Serial Number column
        if "Serial Number" not in df.columns:
            print(f"  Skipping: no 'Serial Number' column found")
            print(f"  Available columns: {list(df.columns)}")
            skipped_files += 1
            continue

        # Get file metadata
        file_created, file_modified = DatasetTemplate.get_file_metadata(csv_path)
        source_filename = os.path.basename(csv_path)

        # Standardize serial number column
        df["Serial Number"] = df["Serial Number"].astype(str).str.strip()

        row_count = 0
        event_count = 0

        for idx, row in df.iterrows():
            serial = str(row.get("Serial Number", "")).strip()
            if not serial or serial.lower() == "nan":
                continue

            row_count += 1

            # Process Acquisition event
            if (
                pd.notnull(row.get("Acquire Date"))
                and str(row.get("Acquire Date")).strip()
            ):
                # Combine address fields
                address = DatasetTemplate.combine_address_fields(
                    row.get("Acquire Address", ""),
                    row.get("Acquire City", ""),
                    row.get("Acquire State", ""),
                    row.get("Acquire Zip", ""),
                )

                # Create standardized record
                record = DatasetTemplate.create_record(
                    serial_number=serial,
                    event_type="Acquisition",
                    event_date=str(row.get("Acquire Date", "")),
                    associated_name=str(row.get("Acquire Name", "")),
                    associated_address=address,
                    source_file=source_filename,
                    file_created=file_created,
                    file_modified=file_modified,
                )

                all_csv_records.append(record.to_dict())
                event_count += 1

            # Process Disposition event
            if (
                pd.notnull(row.get("Disposition Date"))
                and str(row.get("Disposition Date")).strip()
            ):
                # Combine address fields
                address = DatasetTemplate.combine_address_fields(
                    row.get("Disposition Address", ""),
                    row.get("Disposition City", ""),
                    row.get("Disposition State", ""),
                    row.get("Disposition Zip", ""),
                )

                # Create standardized record
                record = DatasetTemplate.create_record(
                    serial_number=serial,
                    event_type="Disposition",
                    event_date=str(row.get("Disposition Date", "")),
                    associated_name=str(row.get("Disposition Name", "")),
                    associated_address=address,
                    source_file=source_filename,
                    file_created=file_created,
                    file_modified=file_modified,
                )

                all_csv_records.append(record.to_dict())
                event_count += 1

        print(f"  Processed {row_count} rows → {event_count} events")
        processed_files += 1

    # Create standardized DataFrame
    if all_csv_records:
        csv_df = pd.DataFrame(all_csv_records)
        csv_df = DatasetTemplate.standardize_dataframe(csv_df)

        print(f"\n" + "=" * 50)
        print(f"CSV PROCESSING SUMMARY")
        print("=" * 50)
        print(f"Files processed: {processed_files}")
        print(f"Files skipped: {skipped_files}")
        print(f"Total events extracted: {len(csv_df)}")
        print(f"Unique serial numbers: {csv_df['serial_number'].nunique()}")

        # Show event type breakdown
        event_types = csv_df["event_type"].value_counts()
        print(f"\nEvent types found:")
        for event_type, count in event_types.items():
            print(f"  {event_type}: {count}")

        # Find serial numbers with multiple events
        serial_counts = csv_df["serial_number"].value_counts()
        multi_event_serials = serial_counts[serial_counts > 1]

        if len(multi_event_serials) > 0:
            print(f"\nSerial numbers with multiple events: {len(multi_event_serials)}")
            print("Top 5 serial numbers by event count:")
            for serial, count in multi_event_serials.head().items():
                print(f"  {serial}: {count} events")

            # Show sample of multi-event records
            sample_serial = multi_event_serials.index[0]
            sample_records = csv_df[
                csv_df["serial_number"] == sample_serial
            ].sort_values("event_date")
            print(f"\nSample records for serial {sample_serial}:")
            for _, record in sample_records.iterrows():
                print(
                    f"  {record['event_date']} - {record['event_type']} - {record['associated_name']}"
                )

        # Save results
        DatasetTemplate.save_to_csv(csv_df, "reports/csv_events_standardized.csv")

        # Save multi-event records if they exist
        if len(multi_event_serials) > 0:
            multi_event_df = csv_df[
                csv_df["serial_number"].isin(multi_event_serials.index)
            ]
            multi_event_df = multi_event_df.sort_values(
                ["serial_number", "event_date", "event_type"]
            )
            DatasetTemplate.save_to_csv(
                multi_event_df, "reports/csv_multi_event_standardized.csv"
            )
            print(f"Saved multi-event records: {len(multi_event_df)} records")

        return csv_df
    else:
        print("\nNo CSV records were extracted.")
        return pd.DataFrame()


# Run CSV processing
if "discovered_files" in globals() and discovered_files:
    csv_results = process_csv_files(discovered_files)

    if not csv_results.empty:
        print(
            f"\n✓ CSV processing complete! {len(csv_results)} standardized records created."
        )
        print("Files saved:")
        print("  - reports/csv_events_standardized.csv (all events)")
        if (
            len(
                csv_results["serial_number"].value_counts()[
                    csv_results["serial_number"].value_counts() > 1
                ]
            )
            > 0
        ):
            print("  - reports/csv_multi_event_standardized.csv (multi-event serials)")
    else:
        print("\n✓ CSV processing complete - no valid records found.")
else:
    print("No discovered_files found. Run file discovery first.")
# Out:
# PROCESSING CSV FILES
# ==================================================
# Found 13 CSV files to process
#
# Processing: AUS Weapons List.csv
#   Loaded 19190 rows, 42 columns
#   Processed 19190 rows → 20501 events
#
# Processing: 20250801_071752_173946_regionInventoryReport (36).csv
#   Loaded 20375 rows, 6 columns
#   Processed 20375 rows → 0 events
#
# Processing: 20250801_071753_217501_AUS Weapons List.csv
#   Loaded 19190 rows, 42 columns
#   Processed 19190 rows → 20501 events
#
# Processing: 20250801_071753_391257_regionInventoryReport (7).csv
#   Loaded 19553 rows, 6 columns
#   Processed 19553 rows → 0 events
#
# Processing: 20250801_071754_795836_Bin Report.csv
#   Loaded 51 rows, 4 columns
#   Processed 51 rows → 0 events
#
# Processing: 20250801_071756_477557_regionInventoryReport (2).csv
#   Loaded 19563 rows, 6 columns
#   Processed 19563 rows → 0 events
#
# Processing: 20250801_071756_913944_branchAssignmentReport (4).csv
#   Loaded 816 rows, 6 columns
#   Processed 816 rows → 0 events
#
# Processing: 20250801_071757_741562_All AUS 3-21-25 1600EST.csv
#   Loaded 20087 rows, 7 columns
#   Processed 20087 rows → 0 events
#
# Processing: 20250801_071801_013951_regionInventoryReport (TC9600-TC9604).csv
#   Loaded 19563 rows, 7 columns
#   Processed 19563 rows → 0 events
#
# Processing: 20250801_071809_474678_regionInventoryReport (35).csv
#   Loaded 20358 rows, 6 columns
#   Processed 20358 rows → 0 events
#
# Processing: 20250801_071809_586470_regionInventoryReport (8).csv
#   Loaded 19539 rows, 6 columns
#   Processed 19539 rows → 0 events
#
# Processing: 20250801_071811_522550_AUS Weapons List.csv
#   Loaded 19190 rows, 42 columns
#   Processed 19190 rows → 20501 events
#
# Processing: 20250801_071812_347446_All AUS 3-14-25 2000EST.csv
#   Loaded 20375 rows, 7 columns
#   Processed 20375 rows → 0 events
#
# ==================================================
# CSV PROCESSING SUMMARY
# ==================================================
# Files processed: 13
# Files skipped: 0
# Total events extracted: 61497
# Unique serial numbers: 19188
#
# Event types found:
#   Acquisition: 57564
#   Disposition: 3933
#
# Serial numbers with multiple events: 19188
# Top 5 serial numbers by event count:
#   BEKS048: 6 events
#   DTA5058: 6 events
#   BUXU922: 6 events
#   BUXU923: 6 events
#   BUXU924: 6 events
#
# Sample records for serial BEKS048:
#   4/17/2017 0:00 - Disposition - MMI Wholesale
#   4/17/2017 0:00 - Disposition - MMI Wholesale
#   4/17/2017 0:00 - Disposition - MMI Wholesale
#   6/3/2020 0:00 - Acquisition - ALLIED BARTON SECURITY SERVICES
#   6/3/2020 0:00 - Acquisition - ALLIED BARTON SECURITY SERVICES
#   6/3/2020 0:00 - Acquisition - ALLIED BARTON SECURITY SERVICES
# Saved 61497 records to reports/csv_events_standardized.csv
# Saved 61497 records to reports/csv_multi_event_standardized.csv
# Saved multi-event records: 61497 records
#
# ✓ CSV processing complete! 61497 standardized records created.
# Files saved:
#   - reports/csv_events_standardized.csv (all events)
#   - reports/csv_multi_event_standardized.csv (multi-event serials)

# %%
# Cell 7: Excel File Processing with DatasetTemplate
# This cell processes all Excel files using the standardized dataset template


def process_excel_files(discovered_files):
    """
    Process all Excel files using the standardized DatasetTemplate.
    """
    # Get Excel files from both .xlsx and .xls keys
    excel_files = []

    if "Excel Files (xlsx)" in discovered_files:
        excel_files.extend(discovered_files["Excel Files (xlsx)"])
        print(f"Found {len(discovered_files['Excel Files (xlsx)'])} .xlsx files")

    if "Excel Files (xls)" in discovered_files:
        excel_files.extend(discovered_files["Excel Files (xls)"])
        print(f"Found {len(discovered_files['Excel Files (xls)'])} .xls files")

    if not excel_files:
        print("No Excel files found for processing.")
        return pd.DataFrame()

    print("PROCESSING EXCEL FILES")
    print("=" * 50)
    print(f"Total Excel files to process: {len(excel_files)}")

    all_excel_records = []
    processed_files = 0
    skipped_files = 0
    total_sheets = 0
    processed_sheets = 0

    # Suppress openpyxl warnings
    warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

    # Header detection keywords
    HEADER_KEYWORDS = [
        "serial",
        "date",
        "acquisition",
        "disposition",
        "inspection",
        "transfer",
        "inventory",
        "name",
        "address",
        "model",
    ]

    def find_header_row(df_head):
        """Scans the top rows of a DataFrame to find the most likely header row."""
        best_score = 0
        header_row_index = -1
        for i, row in df_head.iterrows():
            score = 0
            for cell in row:
                if isinstance(cell, str):
                    for keyword in HEADER_KEYWORDS:
                        if keyword in cell.lower():
                            score += 1
            if score > best_score:
                best_score = score
                header_row_index = i
        return header_row_index if best_score >= 2 else -1

    def process_excel_sheet_with_header(df, sheet_info):
        """Process Excel sheet that has identifiable headers."""
        sheet_records = []
        source_file, sheet_name, file_created, file_modified = sheet_info

        # Ensure all columns are strings
        df.columns = [str(c) for c in df.columns]

        # Find serial number column
        serial_col = next((col for col in df.columns if "serial" in col.lower()), None)
        if not serial_col:
            return []

        # Find name columns (handle split names)
        first_name_col = next(
            (c for c in df.columns if "first" in c.lower() and "name" in c.lower()),
            None,
        )
        last_name_col = next(
            (c for c in df.columns if "last" in c.lower() and "name" in c.lower()), None
        )
        middle_initial_col = next(
            (c for c in df.columns if "middle" in c.lower() or c.lower() == "mi"), None
        )
        full_name_col = next(
            (
                c
                for c in df.columns
                if "name" in c.lower()
                and "first" not in c.lower()
                and "last" not in c.lower()
            ),
            None,
        )

        # Find address columns
        address_col = next((c for c in df.columns if "address" in c.lower()), None)
        city_col = next((c for c in df.columns if "city" in c.lower()), None)
        state_col = next((c for c in df.columns if "state" in c.lower()), None)
        zip_col = next(
            (c for c in df.columns if "zip" in c.lower() or "postal" in c.lower()), None
        )

        # Find date columns (excluding expiration dates)
        IGNORE_IN_DATE = ["exp", "expir"]
        date_columns = [
            col
            for col in df.columns
            if "date" in col.lower()
            and not any(word in col.lower() for word in IGNORE_IN_DATE)
        ]

        for idx, row in df.iterrows():
            serial = str(row.get(serial_col, "")).strip()
            if (
                not serial
                or serial.lower() == "nan"
                or not any(c.isalnum() for c in serial)
            ):
                continue

            # Combine name parts
            associated_name = ""
            if first_name_col and last_name_col:
                # Handle split name columns
                name_parts = []
                first = str(row.get(first_name_col, "")).strip()
                middle = (
                    str(row.get(middle_initial_col, "")).strip()
                    if middle_initial_col
                    else ""
                )
                last = str(row.get(last_name_col, "")).strip()

                if first and first.lower() != "nan":
                    name_parts.append(first)
                if middle and middle.lower() != "nan":
                    name_parts.append(middle)
                if last and last.lower() != "nan":
                    name_parts.append(last)

                associated_name = " ".join(name_parts)
            elif full_name_col:
                # Single name column
                associated_name = str(row.get(full_name_col, "")).strip()
                if associated_name.lower() == "nan":
                    associated_name = ""

            # Combine address fields
            if address_col or city_col or state_col or zip_col:
                address = DatasetTemplate.combine_address_fields(
                    row.get(address_col, "") if address_col else "",
                    row.get(city_col, "") if city_col else "",
                    row.get(state_col, "") if state_col else "",
                    row.get(zip_col, "") if zip_col else "",
                )
            else:
                address = ""

            # Process each date column as separate events
            events_created = 0
            for date_col in date_columns:
                if pd.notnull(row.get(date_col)) and str(row.get(date_col)).strip():
                    # Determine event type from column name
                    event_type = date_col.replace("Date", "").replace("of", "").strip()
                    if not event_type:
                        event_type = "Event"

                    # Create standardized record
                    record = DatasetTemplate.create_record(
                        serial_number=serial,
                        event_type=event_type,
                        event_date=str(row.get(date_col, "")),
                        associated_name=associated_name,
                        associated_address=address,
                        source_file=f"{source_file} ({sheet_name})",
                        file_created=file_created,
                        file_modified=file_modified,
                    )

                    sheet_records.append(record.to_dict())
                    events_created += 1

            # If no date columns found, create inventory record
            if not date_columns or events_created == 0:
                record = DatasetTemplate.create_record(
                    serial_number=serial,
                    event_type="Inventory",
                    event_date="",
                    associated_name=associated_name,
                    associated_address=address,
                    source_file=f"{source_file} ({sheet_name})",
                    file_created=file_created,
                    file_modified=file_modified,
                )

                sheet_records.append(record.to_dict())

        return sheet_records

    def process_excel_sheet_without_header(df, sheet_info):
        """Process Excel sheet by inferring column content when no header is found."""
        sheet_records = []
        source_file, sheet_name, file_created, file_modified = sheet_info

        # Score columns for serial numbers and dates
        col_scores = {col: {"serial": 0, "date": 0} for col in df.columns}
        total_rows = len(df)

        if total_rows == 0:
            return []

        # Sample data to infer column types
        for col in df.columns:
            sample = df[col].dropna()
            if len(sample) > 0:
                sample = sample.sample(n=min(50, len(sample)))
                for cell in sample:
                    # Check for serial number patterns
                    if isinstance(cell, str) and re.match(
                        r"^[A-Z0-9-]{5,20}$", cell, re.IGNORECASE
                    ):
                        col_scores[col]["serial"] += 1
                    # Check for date patterns
                    if pd.to_datetime(cell, errors="coerce") is not pd.NaT:
                        col_scores[col]["date"] += 1

        # Find best serial and date columns
        serial_col = (
            max(col_scores, key=lambda c: col_scores[c]["serial"])
            if col_scores
            else None
        )
        date_col = (
            max(col_scores, key=lambda c: col_scores[c]["date"]) if col_scores else None
        )

        # Validate column reliability
        is_serial_col_valid = (
            serial_col is not None
            and col_scores[serial_col]["serial"] / min(50, total_rows) > 0.2
        )
        is_date_col_valid = (
            date_col is not None
            and col_scores[date_col]["date"] / min(50, total_rows) > 0.2
        )

        if not is_serial_col_valid:
            return []

        # Process rows
        for idx, row in df.iterrows():
            serial = str(row.get(serial_col, "")).strip()
            if not serial or not any(c.isalnum() for c in serial):
                continue

            event_date = str(row.get(date_col, "")) if is_date_col_valid else ""
            event_type = "Inferred Event" if is_date_col_valid else "Inventory"

            # Create standardized record
            record = DatasetTemplate.create_record(
                serial_number=serial,
                event_type=event_type,
                event_date=event_date,
                associated_name="",
                associated_address="",
                source_file=f"{source_file} ({sheet_name})",
                file_created=file_created,
                file_modified=file_modified,
            )

            sheet_records.append(record.to_dict())

        return sheet_records

    # Process each Excel file
    for excel_path in excel_files:
        print(f"\nProcessing: {os.path.basename(excel_path)}")

        try:
            # Get file metadata
            file_created, file_modified = DatasetTemplate.get_file_metadata(excel_path)
            source_filename = os.path.basename(excel_path)

            # Read Excel file
            xls = pd.ExcelFile(excel_path)
            sheet_names = xls.sheet_names
            total_sheets += len(sheet_names)

            print(f"  Found {len(sheet_names)} sheets")

            file_events = 0

            for sheet_name in sheet_names:
                try:
                    sheet_info = (
                        source_filename,
                        sheet_name,
                        file_created,
                        file_modified,
                    )

                    # Read first 10 rows to detect headers
                    df_head = pd.read_excel(
                        xls, sheet_name=sheet_name, header=None, nrows=10
                    )
                    header_row_idx = find_header_row(df_head)

                    if header_row_idx != -1:
                        # Process with detected header
                        df = pd.read_excel(
                            xls, sheet_name=sheet_name, header=header_row_idx, dtype=str
                        )
                        sheet_records = process_excel_sheet_with_header(df, sheet_info)
                    else:
                        # Process without header (infer columns)
                        df = pd.read_excel(
                            xls, sheet_name=sheet_name, header=None, dtype=str
                        )
                        sheet_records = process_excel_sheet_without_header(
                            df, sheet_info
                        )

                    all_excel_records.extend(sheet_records)
                    file_events += len(sheet_records)
                    processed_sheets += 1

                    if sheet_records:
                        print(f"    Sheet '{sheet_name}': {len(sheet_records)} events")
                    else:
                        print(f"    Sheet '{sheet_name}': No valid data found")

                except Exception as sheet_error:
                    print(f"    Sheet '{sheet_name}': Error - {sheet_error}")
                    continue

            print(f"  Total events from file: {file_events}")
            processed_files += 1

        except Exception as file_error:
            print(f"  Error reading file: {file_error}")
            skipped_files += 1
            continue

    # Create standardized DataFrame and generate summary
    if all_excel_records:
        excel_df = pd.DataFrame(all_excel_records)
        excel_df = DatasetTemplate.standardize_dataframe(excel_df)

        print(f"\n" + "=" * 50)
        print(f"EXCEL PROCESSING SUMMARY")
        print("=" * 50)
        print(f"Files processed: {processed_files}")
        print(f"Files skipped: {skipped_files}")
        print(f"Sheets processed: {processed_sheets}/{total_sheets}")
        print(f"Total events extracted: {len(excel_df)}")
        print(f"Unique serial numbers: {excel_df['serial_number'].nunique()}")

        # Show event type breakdown
        event_types = excel_df["event_type"].value_counts()
        print(f"\nEvent types found:")
        for event_type, count in event_types.items():
            print(f"  {event_type}: {count}")

        # Find and analyze multi-event serials
        serial_counts = excel_df["serial_number"].value_counts()
        multi_event_serials = serial_counts[serial_counts > 1]

        if len(multi_event_serials) > 0:
            print(f"\nSerial numbers with multiple events: {len(multi_event_serials)}")
            print("Top 5 serial numbers by event count:")
            for serial, count in multi_event_serials.head().items():
                print(f"  {serial}: {count} events")

        # Save results
        DatasetTemplate.save_to_csv(excel_df, "reports/excel_events_standardized.csv")

        if len(multi_event_serials) > 0:
            multi_event_df = excel_df[
                excel_df["serial_number"].isin(multi_event_serials.index)
            ]
            multi_event_df = multi_event_df.sort_values(
                ["serial_number", "event_date", "event_type"]
            )
            DatasetTemplate.save_to_csv(
                multi_event_df, "reports/excel_multi_event_standardized.csv"
            )
            print(f"Saved multi-event records: {len(multi_event_df)} records")

        return excel_df
    else:
        print("\nNo Excel records were extracted.")
        return pd.DataFrame()


# Run Excel processing
if "discovered_files" in globals() and discovered_files:
    excel_results = process_excel_files(discovered_files)

    if not excel_results.empty:
        print(
            f"\n✓ Excel processing complete! {len(excel_results)} standardized records created."
        )
        print("Files saved:")
        print("  - reports/excel_events_standardized.csv (all events)")
        if (
            len(
                excel_results["serial_number"].value_counts()[
                    excel_results["serial_number"].value_counts() > 1
                ]
            )
            > 0
        ):
            print(
                "  - reports/excel_multi_event_standardized.csv (multi-event serials)"
            )
    else:
        print("\n✓ Excel processing complete - no valid records found.")
else:
    print("No discovered_files found. Run file discovery first.")
# Out:
# Found 345 .xlsx files
# Found 33 .xls files
# PROCESSING EXCEL FILES
# ==================================================
# Total Excel files to process: 378
#
# Processing: Unassigned Orchid Fireams as of 1300CST 03172025.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 5836 events
#   Total events from file: 5836
#
# Processing: 2022 Weapon Inventory Form.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 251 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 251
#
# Processing: Murray Weapons (2).xlsx
#   Found 13 sheets
#     Sheet 'Overview Report': No valid data found
#     Sheet 'Transfer Weapons': No valid data found
#     Sheet 'Chattanooga TN': 42 events
#     Sheet 'Knoxville TN': 31 events
#     Sheet 'Tri-Cities TN': 31 events
#     Sheet 'Nashville TN': 54 events
#     Sheet 'Louisville KY': 49 events
#     Sheet 'Decatur AL': 29 events
#     Sheet 'Atlanta GA': 4 events
#     Sheet 'Jackson TN': 24 events
#     Sheet 'Memphis TN': 29 events
#     Sheet 'Birmingham AL': 13 events
#     Sheet 'Branch Addresses': 29 events
#   Total events from file: 335
#
# Processing: Master Certification List MAC45.xlsx
#   Found 3 sheets
#     Sheet 'ACTIVE': 106 events
#     Sheet 'STATISTICS': No valid data found
#     Sheet 'LEGEND': No valid data found
#   Total events from file: 106
#
# Processing: 4-29-2021 IN-SAFE 4144 Weapons Inventory.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 79 events
#   Total events from file: 79
#
# Processing: Dallas Workbook.xlsx
#   Found 2 sheets
#     Sheet 'Combined A&D': 8672 events
#     Sheet 'Dallas Inv': 249 events
#   Total events from file: 8921
#
# Processing: Central AUS Inventory.xlsx
#   Found 2 sheets
#     Sheet 'Sheet2': 1090 events
#     Sheet 'Inventory': 1177 events
#   Total events from file: 2267
#
# Processing: AUS FFL Workbook 06_02_22 JCG.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 19820 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 19820
#
# Processing: ABSS FFL A&D Log 06_19_2019 with location.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 7074 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 7074
#
# Processing: Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 2021 Central Inventory Form.xlsx
#   Found 4 sheets
#     Sheet 'Sheet1': 1440 events
#     Sheet 'Sheet4': No valid data found
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 1440
#
# Processing: AUS-USSA Firearm Inventory.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': 58 events
#     Sheet 'MA': 547 events
#     Sheet 'MW': 59 events
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': 249 events
#     Sheet 'SW': 104 events
#     Sheet 'Source Data': 2184 events
#   Total events from file: 3201
#
# Processing: Copy of 20250320 - Firearm audit worksheet.xlsx
#   Found 5 sheets
#     Sheet 'Issues by branch': No valid data found
#     Sheet 'List of all weapons (3-18)': 20296 events
#     Sheet 'List of WV weapons to sell': 324 events
#     Sheet 'Open FIM - SW': 346 events
#     Sheet 'Field says not in Orchid': 315 events
#   Total events from file: 21281
#
# Processing: New AUS FFL A&D Log 07_03_2019 with location.xlsx
#   Found 2 sheets
#     Sheet 'AUS A&D Log': 4887 events
#     Sheet 'Sheet1': No valid data found
#   Total events from file: 4887
#
# Processing: AUS-USSA Firearm Workbook.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'Master': 1014 events
#     Sheet 'MA': 547 events
#     Sheet 'MW': 59 events
#     Sheet 'NE': No valid data found
#     Sheet 'NW': 4 events
#     Sheet 'SE': 249 events
#     Sheet 'SW': 104 events
#     Sheet 'Source Data': 2184 events
#   Total events from file: 4161
#
# Processing: Expected FA.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 576 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 576
#
# Processing: CE Region Inv Report7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (2)': 2318 events
#   Total events from file: 2318
#
# Processing: Dallas Branch 600+.xlsx
#   Found 1 sheets
#     Sheet 'Dallas BIN': 696 events
#   Total events from file: 696
#
# Processing: Weapons comparison v 1.xlsx
#   Found 4 sheets
#     Sheet 'regionInventoryReport (3)': 17707 events
#     Sheet 'Possible matches to work on': 212 events
#     Sheet 'Fixed Asset master': 57928 events
#     Sheet '2024 adds': 746 events
#   Total events from file: 76593
#
# Processing: FFL Workbook 6_3_20 to ND.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 9469 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 9469
#
# Processing: 20250801_071751_063126_ATF Bundle 04 28APR25 AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071751_159868_CE Deltas 031425.xlsx
#   Found 16 sheets
#     Sheet 'Sheet3': No valid data found
#     Sheet 'Little Rock': 21 events
#     Sheet 'Baton Rouge': 31 events
#     Sheet 'New Orleans': 48 events
#     Sheet 'Shreveport': 6 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 28 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'ElPaso Border Region': 31 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas Area': 268 events
#     Sheet 'Houston Area': 163 events
#     Sheet 'SanAntonio': 65 events
#     Sheet 'SA RGV': 6 events
#     Sheet 'Temple Waco': 5 events
#     Sheet 'regionInventoryReport (54)': 754 events
#   Total events from file: 1501
#
# Processing: 20250801_071751_177822_All AUS 3-13-25 1300.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (49)': 20358 events
#   Total events from file: 20358
#
# Processing: 20250801_071751_207665_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': No valid data found
#     Sheet '2025.03.28': No valid data found
#     Sheet '2025.04.07': No valid data found
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19603
#
# Processing: 20250801_071751_231392_Orchid to Orchid comparision 3-25-25.xlsx
#   Found 2 sheets
#     Sheet '3-25-25': 19663 events
#     Sheet 'Sheet1': 2614 events
#   Total events from file: 22277
#
# Processing: 20250801_071751_246630_2021 Central Inventory Form.xlsx
#   Found 4 sheets
#     Sheet 'Sheet1': 1440 events
#     Sheet 'Sheet4': No valid data found
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 1440
#
# Processing: 20250801_071751_248635_Expected FA.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 576 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 576
#
# Processing: 20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071751_850275_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071751_879868_Firearms Photo Log ATF.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071751_918449_Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 20250801_071751_920857_1300 & 4144 Weapons Inventory.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 98 events
#   Total events from file: 98
#
# Processing: 20250801_071752_005293_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071752_027109_All AUS 9APR25 1700.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (88)': 19603 events
#   Total events from file: 19603
#
# Processing: 20250801_071752_040656_regionInventoryReport (28)1200 031025.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'PIVOT': No valid data found
#     Sheet 'Little Rock': 23 events
#     Sheet 'Baton Rouge': 43 events
#     Sheet 'New Orleans': 58 events
#     Sheet 'Shreveport': 2 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 71 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'Border Region': 34 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas': 367 events
#     Sheet 'E TX': 22 events
#     Sheet 'Houston': 190 events
#     Sheet 'San Antonio': 67 events
#     Sheet 'San Antonio RGV': 6 events
#     Sheet 'TempleWaco': 5 events
#     Sheet 'regionInventoryReport (28)': 963 events
#   Total events from file: 1942
#
# Processing: 20250801_071752_063189_All AUS 3-13-25 1730.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 23 events
#     Sheet 'Sheet2': 285 events
#     Sheet 'regionInventoryReport (51)': 20358 events
#   Total events from file: 20666
#
# Processing: 20250801_071752_078522_ATF Bundle 04 28APR25 AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071752_106410_CE Audit 042925 EoD.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#   Total events from file: 2930
#
# Processing: 20250801_071752_118126_ATF Bundle 04 28APR25 AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071752_131614_ATF Bundle 04 (2025-04-25) Final.xlsx
#   Found 1 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 1552 events
#   Total events from file: 1552
#
# Processing: 20250801_071752_143108_AUS-USSA Firearm Workbook.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'Master': 1014 events
#     Sheet 'MA': 547 events
#     Sheet 'MW': 59 events
#     Sheet 'NE': No valid data found
#     Sheet 'NW': 4 events
#     Sheet 'SE': 249 events
#     Sheet 'SW': 104 events
#     Sheet 'Source Data': 2184 events
#   Total events from file: 4161
#
# Processing: 20250801_071752_201059_Firearms Photo Log ATF.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071752_222746_All AUS 3Apr25 1715EST.xlsx
#   Found 1 sheets
#     Sheet '3Apr25': 19633 events
#   Total events from file: 19633
#
# Processing: 20250801_071752_281286_CE Audit 040825 0800hrs.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (6)': 2877 events
#   Total events from file: 2895
#
# Processing: 20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': 77 events
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2261
#
# Processing: 20250801_071752_323648_FFL Workbook 7_11_20 to ND - Copy.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 9469 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 9469
#
# Processing: 20250801_071752_350207_Firearms Photo Log ATF.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071752_380254_Orchid Full List 03132025.xlsx
#   Found 3 sheets
#     Sheet 'Orchid Full Export 031325': 20277 events
#     Sheet 'Unassigned From Full Export': 8504 events
#     Sheet '2024 DOMO Inevntory FULL': 16157 events
#   Total events from file: 44938
#
# Processing: 20250801_071752_409108_20250320 - Firearm audit worksheet.xlsx
#   Found 5 sheets
#     Sheet 'Issues by branch': No valid data found
#     Sheet 'List of all weapons (3-18)': 20296 events
#     Sheet 'List of WV weapons to sell': 324 events
#     Sheet 'Open FIM - SW': 346 events
#     Sheet 'Field says not in Orchid': 315 events
#   Total events from file: 21281
#
# Processing: 20250801_071752_452383_regionInventoryReport (45) 1700 031225.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 17 events
#     Sheet 'regionInventoryReport (45)': 2862 events
#   Total events from file: 2879
#
# Processing: 20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': 29 events
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': 184 events
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2397
#
# Processing: 20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
#   Found 6 sheets
#     Sheet 'SOURCE DATA': 19820 events
#     Sheet 'OK': 17560 events
#     Sheet 'Duplicate Open SNs': 602 events
#     Sheet 'Issues with Region Branch': 1649 events
#     Sheet 'IGNORE': 9 events
#     Sheet 'Sheet2': No valid data found
#   Total events from file: 39640
#
# Processing: 20250801_071752_609944_All AUS 10APR25 1700EST.xlsx
#   Found 1 sheets
#     Sheet '10APR25': 19603 events
#   Total events from file: 19603
#
# Processing: 20250801_071752_637113_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': No valid data found
#     Sheet '2025.03.28': No valid data found
#     Sheet '2025.04.07': No valid data found
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19603
#
# Processing: 20250801_071752_648782_CE Audit 031425.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (54)': 2888 events
#   Total events from file: 2906
#
# Processing: 20250801_071752_702235_AUS FFL Workbook 06_02_22 JCG.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 19820 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 19820
#
# Processing: 20250801_071752_708856_AUS Weapons Audit (3).xlsx
#   Found 6 sheets
#     Sheet 'Master': No valid data found
#     Sheet 'Armory': 81 events
#     Sheet 'SSOB': 1 events
#     Sheet 'SDC': 1 events
#     Sheet 'Monson State Hospital': No valid data found
#     Sheet 'DATA Sheet': No valid data found
#   Total events from file: 83
#
# Processing: 20250801_071752_789552_CE Deltas 031425.xlsx
#   Found 16 sheets
#     Sheet 'Sheet3': No valid data found
#     Sheet 'Little Rock': 21 events
#     Sheet 'Baton Rouge': 31 events
#     Sheet 'New Orleans': 48 events
#     Sheet 'Shreveport': 6 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 28 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'ElPaso Border Region': 31 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas Area': 268 events
#     Sheet 'Houston Area': 163 events
#     Sheet 'SanAntonio': 65 events
#     Sheet 'SA RGV': 6 events
#     Sheet 'Temple Waco': 5 events
#     Sheet 'regionInventoryReport (54)': 754 events
#   Total events from file: 1501
#
# Processing: 20250801_071752_805835_ATF Bundle 04 28APR25 AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071752_822438_CE Audit 042825 6pm.xlsx
#   Found 7 sheets
#     Sheet 'Sheet1': 19 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#     Sheet 'Lane': 62 events
#     Sheet 'West': 61 events
#     Sheet 'Todd': 42 events
#     Sheet 'Daniels': 18 events
#     Sheet 'Rekow': 72 events
#   Total events from file: 3186
#
# Processing: 20250801_071752_833843_ATF Bundle 04 - RPOC review 24APR25.xlsx
#   Found 1 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 1565 events
#   Total events from file: 1565
#
# Processing: 20250801_071752_944316_Orchid Project - Daily Report of Reconciled Firearms [manually updated weekdays at 0800CST and 1330CST].xlsx
#   Found 1 sheets
#     Sheet 'data': 849 events
#   Total events from file: 849
#
# Processing: 20250801_071752_960656_All AUS 3-27-1725EST.xlsx
#   Found 1 sheets
#     Sheet 'All AUS': 19556 events
#   Total events from file: 19556
#
# Processing: 20250801_071752_980530_All AUS 4-4-25 1700EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (83)': 19618 events
#   Total events from file: 19618
#
# Processing: 20250801_071753_000072_All AUS 3-17-25 1830EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (55)': 20376 events
#   Total events from file: 20376
#
# Processing: 20250801_071753_031023_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071753_045027_regionInventoryReport (28)1200 031025.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'PIVOT': No valid data found
#     Sheet 'Little Rock': 23 events
#     Sheet 'Baton Rouge': 43 events
#     Sheet 'New Orleans': 58 events
#     Sheet 'Shreveport': 2 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 71 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'Border Region': 34 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas': 367 events
#     Sheet 'E TX': 22 events
#     Sheet 'Houston': 190 events
#     Sheet 'San Antonio': 67 events
#     Sheet 'San Antonio RGV': 6 events
#     Sheet 'TempleWaco': 5 events
#     Sheet 'regionInventoryReport (28)': 963 events
#   Total events from file: 1942
#
# Processing: 20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': 77 events
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2261
#
# Processing: 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (51)': 20358 events
#   Total events from file: 20358
#
# Processing: 20250801_071753_088114_CE Region Inv Report7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (2)': 2318 events
#   Total events from file: 2318
#
# Processing: 20250801_071753_088562_NE Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1082 events
#   Total events from file: 1082
#
# Processing: 20250801_071753_088834_MA Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1266 events
#   Total events from file: 1266
#
# Processing: 20250801_071753_089112_SE Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 3485 events
#   Total events from file: 3485
#
# Processing: 20250801_071753_089641_FL Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 5312 events
#   Total events from file: 5312
#
# Processing: 20250801_071753_090327_MW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1078 events
#   Total events from file: 1078
#
# Processing: 20250801_071753_090595_SW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 2099 events
#   Total events from file: 2099
#
# Processing: 20250801_071753_090961_NW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 919 events
#   Total events from file: 919
#
# Processing: 20250801_071753_104308_Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 20250801_071753_122485_FFL Workbook 6_3_20 to ND.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 9469 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 9469
#
# Processing: 20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': 29 events
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': 184 events
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2397
#
# Processing: 20250801_071753_250489_Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 20250801_071753_266732_regionInventoryReport (19) 030625 EOD.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'Sheet3': No valid data found
#     Sheet 'regionInventoryReport (19)': 1132 events
#   Total events from file: 1148
#
# Processing: 20250801_071753_273184_CE Audit 041625 - Caileen Copy .xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (12)': 2878 events
#   Total events from file: 2896
#
# Processing: 20250801_071753_283656_regionInventoryReport (45) 1700 031225.xlsx
#   Found 8 sheets
#     Sheet 'Detail1': 305 events
#     Sheet 'Detail2': 116 events
#     Sheet 'Detail3': 5 events
#     Sheet 'Detail4': 22 events
#     Sheet 'Detail5': 32 events
#     Sheet 'Detail6': 19 events
#     Sheet 'Sheet1': 17 events
#     Sheet 'regionInventoryReport (45)': 2862 events
#   Total events from file: 3378
#
# Processing: 20250801_071753_300346_All AUS 3-18-25 1441.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (58)': 20376 events
#   Total events from file: 20376
#
# Processing: 20250801_071753_321319_4.15.25 AUS Orchid.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (12)': 19574 events
#   Total events from file: 19574
#
# Processing: 20250801_071753_398649_Active Licenses (1).xlsx
#   Found 1 sheets
#     Sheet 'data': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071753_409132_Expired Licenses (1).xlsx
#   Found 1 sheets
#     Sheet 'data': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071753_430518_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071753_459051_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071753_485725_CE Audit 042825 6pm.xlsx
#   Found 7 sheets
#     Sheet 'Sheet1': 19 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#     Sheet 'Lane': 62 events
#     Sheet 'West': 61 events
#     Sheet 'Todd': 42 events
#     Sheet 'Daniels': 18 events
#     Sheet 'Rekow': 72 events
#   Total events from file: 3186
#
# Processing: 20250801_071753_496762_ATF Bundle 04 (2025-04-25) Final.xlsx
#   Found 1 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 1552 events
#   Total events from file: 1552
#
# Processing: 20250801_071753_518245_CE Audit 042925 EoD.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#   Total events from file: 2930
#
# Processing: 20250801_071753_520078_CE Audit 042825 6pm.xlsx
#   Found 7 sheets
#     Sheet 'Sheet1': 19 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#     Sheet 'Lane': 62 events
#     Sheet 'West': 61 events
#     Sheet 'Todd': 42 events
#     Sheet 'Daniels': 18 events
#     Sheet 'Rekow': 72 events
#   Total events from file: 3186
#
# Processing: 20250801_071753_554873_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071753_576711_Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 20250801_071753_605565_Orchid Employee Dupes.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 19553 events
#   Total events from file: 19553
#
# Processing: 20250801_071753_628175_All AUS 4-11-25 1630EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (90)': 19604 events
#   Total events from file: 19604
#
# Processing: 20250801_071753_641734_regionInventoryReport (28)1200 031025.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'PIVOT': No valid data found
#     Sheet 'Little Rock': 23 events
#     Sheet 'Baton Rouge': 43 events
#     Sheet 'New Orleans': 58 events
#     Sheet 'Shreveport': 2 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 71 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'Border Region': 34 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas': 367 events
#     Sheet 'E TX': 22 events
#     Sheet 'Houston': 190 events
#     Sheet 'San Antonio': 67 events
#     Sheet 'San Antonio RGV': 6 events
#     Sheet 'TempleWaco': 5 events
#     Sheet 'regionInventoryReport (28)': 963 events
#   Total events from file: 1942
#
# Processing: 20250801_071753_649073_ATF Bundle 1 3-17-25.xlsx
#   Found 2 sheets
#     Sheet 'TOTAL': 5723 events
#     Sheet 'ATF Batch 1': 2846 events
#   Total events from file: 8569
#
# Processing: 20250801_071753_860733_Equipment Inventory Previous.xlsx
#   Found 2 sheets
#     Sheet 'Safe': 57 events
#     Sheet 'Uniforms': No valid data found
#   Total events from file: 57
#
# Processing: 20250801_071753_891292_Equipment Inventory Current 2025.xlsx
#   Found 2 sheets
#     Sheet 'Safe': 57 events
#     Sheet 'Uniforms': No valid data found
#   Total events from file: 57
#
# Processing: 20250801_071753_938809_Firearms Photo Log ATF.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071753_948167_4-29-2021 IN-SAFE 4144 Weapons Inventory.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 79 events
#   Total events from file: 79
#
# Processing: 20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071753_991884_regionInventoryReport (14).xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'regionInventoryReport (14)': 2595 events
#   Total events from file: 2611
#
# Processing: 20250801_071754_028534_Central AUS Inventory.xlsx
#   Found 2 sheets
#     Sheet 'Sheet2': 1090 events
#     Sheet 'Inventory': 1177 events
#   Total events from file: 2267
#
# Processing: 20250801_071754_029449_Dallas Workbook.xlsx
#   Found 2 sheets
#     Sheet 'Combined A&D': 8672 events
#     Sheet 'Dallas Inv': 249 events
#   Total events from file: 8921
#
# Processing: 20250801_071754_033190_ABSS FFL A&D Log 06_19_2019 with location.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 7074 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 7074
#
# Processing: 20250801_071754_036315_New AUS FFL A&D Log 07_03_2019 with location.xlsx
#   Found 2 sheets
#     Sheet 'AUS A&D Log': 4887 events
#     Sheet 'Sheet1': No valid data found
#   Total events from file: 4887
#
# Processing: 20250801_071754_062311_All AUS 3-17-25 1330EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (54)': 20374 events
#   Total events from file: 20374
#
# Processing: 20250801_071754_082742_All AUS 3-11-25PM.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (46)': 20324 events
#   Total events from file: 20324
#
# Processing: 20250801_071754_105927_regionInventoryReport (8).xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (8)': 19538 events
#   Total events from file: 19538
#
# Processing: 20250801_071754_133364_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': No valid data found
#     Sheet '2025.03.28': No valid data found
#     Sheet '2025.04.07': No valid data found
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19603
#
# Processing: 20250801_071754_148234_regionInventoryReport (28)1200 031025.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'PIVOT': No valid data found
#     Sheet 'Little Rock': 23 events
#     Sheet 'Baton Rouge': 43 events
#     Sheet 'New Orleans': 58 events
#     Sheet 'Shreveport': 2 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 71 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'Border Region': 34 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas': 367 events
#     Sheet 'E TX': 22 events
#     Sheet 'Houston': 190 events
#     Sheet 'San Antonio': 67 events
#     Sheet 'San Antonio RGV': 6 events
#     Sheet 'TempleWaco': 5 events
#     Sheet 'regionInventoryReport (28)': 963 events
#   Total events from file: 1942
#
# Processing: 20250801_071754_179712_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071754_205973_CE Audit 042925 EoD.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#   Total events from file: 2930
#
# Processing: 20250801_071754_207752_CE Audit 042825 6pm.xlsx
#   Found 7 sheets
#     Sheet 'Sheet1': 19 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#     Sheet 'Lane': 62 events
#     Sheet 'West': 61 events
#     Sheet 'Todd': 42 events
#     Sheet 'Daniels': 18 events
#     Sheet 'Rekow': 72 events
#   Total events from file: 3186
#
# Processing: 20250801_071754_219868_ATF Bundle 04 (2025-04-24) AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 1565 events
#     Sheet 'Sheet3': 7602 events
#   Total events from file: 9167
#
# Processing: 20250801_071754_247415_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071754_268016_ATF Bundle 04 28APR25 AMT Rec For NE 5.1.25 update.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071754_273179_Bundle 4 Serial Numbers - Not Found in Orchid IM.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 923 events
#   Total events from file: 923
#
# Processing: 20250801_071754_328659_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned V2.xlsx
#   Found 3 sheets
#     Sheet '2025.03.19': No valid data found
#     Sheet 'AllAUS': 19603 events
#     Sheet 'AD Book 1-20': 25771 events
#   Total events from file: 45374
#
# Processing: 20250801_071754_355038_regionInventoryReport (19) 030625 EOD.xlsx
#   Found 3 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'Sheet3': No valid data found
#     Sheet 'regionInventoryReport (19)': 1132 events
#   Total events from file: 1148
#
# Processing: 20250801_071754_372614_All AUS 3-28-25 AM.xlsx
#   Found 2 sheets
#     Sheet 'regionInventoryReport (73)': 19534 events
#     Sheet 'All AUS 3-28-25 AM': 3460 events
#   Total events from file: 22994
#
# Processing: 20250801_071754_493854_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
#   Found 4 sheets
#     Sheet 'Detail1': No valid data found
#     Sheet 'Sheet3': No valid data found
#     Sheet 'data': No valid data found
#     Sheet 'Sheet1': 19587 events
#   Total events from file: 19587
#
# Processing: 20250801_071754_517949_CE Inventory 1015 032625.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (77)': 2894 events
#     Sheet 'Deltas': No valid data found
#     Sheet 'Little Rock': 14 events
#     Sheet 'Baton Rouge': 17 events
#     Sheet 'New Orleans': 32 events
#     Sheet 'Oklahoma': 11 events
#     Sheet 'Austin': 24 events
#     Sheet 'Beaumont': 32 events
#     Sheet 'Border Region': 32 events
#     Sheet 'Corpus Christi': 1 events
#     Sheet 'DFW': 209 events
#     Sheet 'E TX': 7 events
#     Sheet 'Houston': 100 events
#     Sheet 'San Antonio': 39 events
#     Sheet 'SA RGV': 5 events
#     Sheet 'TempleWaco': 2 events
#     Sheet 'regionInventoryReport (78)': 525 events
#   Total events from file: 3962
#
# Processing: 20250801_071754_546297_FIM Tickets 2025.03.25 with Outstanding Serial Numbers.xlsx
#   Found 5 sheets
#     Sheet 'regionInventoryReport (69)': 19648 events
#     Sheet 'Serial Numbers -3701 Remaining': No valid data found
#     Sheet 'FIM Tickets': 377 events
#     Sheet 'CONFIDENTIAL - Subset of 3701': 168 events
#     Sheet '2019 Research Database': 1803 events
#   Total events from file: 21996
#
# Processing: 20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': 77 events
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2261
#
# Processing: 20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071754_648661_regionInventoryReport (28)1200 031025.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 16 events
#     Sheet 'PIVOT': No valid data found
#     Sheet 'Little Rock': 23 events
#     Sheet 'Baton Rouge': 43 events
#     Sheet 'New Orleans': 58 events
#     Sheet 'Shreveport': 2 events
#     Sheet 'Oklahoma': 19 events
#     Sheet 'Austin': 71 events
#     Sheet 'Beaumont': 53 events
#     Sheet 'Border Region': 34 events
#     Sheet 'Corpus': 3 events
#     Sheet 'Dallas': 367 events
#     Sheet 'E TX': 22 events
#     Sheet 'Houston': 190 events
#     Sheet 'San Antonio': 67 events
#     Sheet 'San Antonio RGV': 6 events
#     Sheet 'TempleWaco': 5 events
#     Sheet 'regionInventoryReport (28)': 963 events
#   Total events from file: 1942
#
# Processing: 20250801_071754_666979_Hagues in Orchid 3-26-25.xlsx
#   Found 2 sheets
#     Sheet 'regionInventoryReport (69)': 19648 events
#     Sheet 'Hagues': 1130 events
#   Total events from file: 20778
#
# Processing: 20250801_071754_673093_Weapons Database - Area 16.xlsx
#   Found 2 sheets
#     Sheet 'Company Owned': 240 events
#     Sheet 'Personally Owned': 110 events
#   Total events from file: 350
#
# Processing: 20250801_071754_683418_CE Region Inv Report7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (2)': 2318 events
#   Total events from file: 2318
#
# Processing: 20250801_071754_683926_NE Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1082 events
#   Total events from file: 1082
#
# Processing: 20250801_071754_684205_MA Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1266 events
#   Total events from file: 1266
#
# Processing: 20250801_071754_684495_SE Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 3485 events
#   Total events from file: 3485
#
# Processing: 20250801_071754_685008_FL Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 5312 events
#   Total events from file: 5312
#
# Processing: 20250801_071754_685689_MW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 1078 events
#   Total events from file: 1078
#
# Processing: 20250801_071754_685941_SW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 2099 events
#   Total events from file: 2099
#
# Processing: 20250801_071754_686296_NW Region Inv Report 7_19_23.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (1)': 919 events
#   Total events from file: 919
#
# Processing: 20250801_071754_771090_Copy of Copy of Project Vinson weapons inventory (002).xlsx
#   Found 2 sheets
#     Sheet 'Master File': 88 events
#     Sheet 'Inspected': 85 events
#   Total events from file: 173
#
# Processing: 20250801_071754_771620_Yall 3_3_2017.xlsx
#   Found 1 sheets
#     Sheet 'Sheet1': 24 events
#   Total events from file: 24
#
# Processing: 20250801_071754_771868_APS.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 1274 events
#     Sheet 'Sheet2': 1294 events
#   Total events from file: 2568
#
# Processing: 20250801_071754_774382_G4S Closeout A&D.xlsx
#   Found 1 sheets
#     Sheet 'ATF_Bound_Book_06172022': 36372 events
#   Total events from file: 36372
#
# Processing: 20250801_071754_810436_ATF Bundle 04 28APR25 AMT Rec For NE 5.1.25.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071754_836128_All AUS 18APR25 1545.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (95)': 19439 events
#   Total events from file: 19439
#
# Processing: 20250801_071754_944292_Mercury Campaign SN Inputs  - SNs Unassigned v05122025.xlsx
#   Found 3 sheets
#     Sheet 'Remaining Mercury SNs': No valid data found
#     Sheet 'Burn Down List': No valid data found
#     Sheet 'rawdata': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071755_005046_Firearms Reported - Not in A&D Rev. 4-18-25.xlsx
#   Found 5 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'Other additional forms': 23 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19830
#
# Processing: 20250801_071755_039280_ATF Bundle 04 (2025-04-23) - v2.0 DRAFT.xlsx
#   Found 1 sheets
#     Sheet 'Sheet3': 7602 events
#   Total events from file: 7602
#
# Processing: 20250801_071755_605217_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071755_640710_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071755_657965_ATF Bundle 04 28APR25 AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071755_680586_Orchid to Orchid comparision 3-25-25.xlsx
#   Found 2 sheets
#     Sheet '3-25-25': 19663 events
#     Sheet 'Sheet1': 2614 events
#   Total events from file: 22277
#
# Processing: 20250801_071755_692956_CE Inventory 1015 032625.xlsx
#   Found 18 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (77)': 2894 events
#     Sheet 'Deltas': No valid data found
#     Sheet 'Little Rock': 14 events
#     Sheet 'Baton Rouge': 17 events
#     Sheet 'New Orleans': 32 events
#     Sheet 'Oklahoma': 11 events
#     Sheet 'Austin': 24 events
#     Sheet 'Beaumont': 32 events
#     Sheet 'Border Region': 32 events
#     Sheet 'Corpus Christi': 1 events
#     Sheet 'DFW': 209 events
#     Sheet 'E TX': 7 events
#     Sheet 'Houston': 100 events
#     Sheet 'San Antonio': 39 events
#     Sheet 'SA RGV': 5 events
#     Sheet 'TempleWaco': 2 events
#     Sheet 'regionInventoryReport (78)': 525 events
#   Total events from file: 3962
#
# Processing: 20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx
#   Found 9 sheets
#     Sheet 'Dashboard': No valid data found
#     Sheet 'CE': No valid data found
#     Sheet 'MA': No valid data found
#     Sheet 'MW': No valid data found
#     Sheet 'NE': No valid data found
#     Sheet 'NW': No valid data found
#     Sheet 'SE': No valid data found
#     Sheet 'SW': No valid data found
#     Sheet 'Source Data': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071755_769119_All AUS 3-26-25 1700EST.xlsx
#   Found 1 sheets
#     Sheet 'All AUS 3-26-25 1700EST': 19650 events
#   Total events from file: 19650
#
# Processing: 20250801_071755_789340_All AUS 4-1-25 1830EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (78)': 19529 events
#   Total events from file: 19529
#
# Processing: 20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071755_847434_All AUS 3-31-25 1700EST.xlsx
#   Found 1 sheets
#     Sheet 'regionInventoryReport (77)': 19539 events
#   Total events from file: 19539
#
# Processing: 20250801_071755_864743_regionInventoryReport (45) 1700 031225.xlsx
#   Found 8 sheets
#     Sheet 'Detail1': 305 events
#     Sheet 'Detail2': 116 events
#     Sheet 'Detail3': 5 events
#     Sheet 'Detail4': 22 events
#     Sheet 'Detail5': 32 events
#     Sheet 'Detail6': 19 events
#     Sheet 'Sheet1': 17 events
#     Sheet 'regionInventoryReport (45)': 2862 events
#   Total events from file: 3378
#
# Processing: 20250801_071755_880465_ATF Bundle 04 28APR25 AMT Rec For NE 5.1.25.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071755_899335_ATF Bundle 04 (2025-04-23) - v2.0 DRAFT.xlsx
#   Found 1 sheets
#     Sheet 'Sheet3': 7602 events
#   Total events from file: 7602
#
# Processing: 20250801_071755_929120_CE Audit 042825 6pm.xlsx
#   Found 7 sheets
#     Sheet 'Sheet1': 19 events
#     Sheet 'regionInventoryReport (1)': 2912 events
#     Sheet 'Lane': 62 events
#     Sheet 'West': 61 events
#     Sheet 'Todd': 42 events
#     Sheet 'Daniels': 18 events
#     Sheet 'Rekow': 72 events
#   Total events from file: 3186
#
# Processing: 20250801_071755_948663_ATF Bundle 04 (2025-04-24) AMT Rec.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 1565 events
#     Sheet 'Sheet3': 7602 events
#   Total events from file: 9167
#
# Processing: 20250801_071755_973955_Firearms Reported - Not in A&D Rev. 4-15-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.04.07': 4 events
#     Sheet '2025.03.28': 170 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: 20250801_071755_981333_AUS Bundle 5 61625.xlsx
#   Found 1 sheets
#     Sheet 'Sheet2': 1139 events
#   Total events from file: 1139
#
# Processing: 20250801_071756_054846_Mercury Campaign SN Inputs  - SNs Unassigned v05082025.xlsx
#   Found 2 sheets
#     Sheet 'Sheet4': No valid data found
#     Sheet 'data': 3312 events
#   Total events from file: 3312
#
# Processing: 20250801_071756_092614_ATF Bundle 04 28APR25 AMT Rec For NE 5.1.25.xlsx
#   Found 2 sheets
#     Sheet 'AMT Bundle 4 Recommendation 1': 225 events
#     Sheet 'AMT ': 7602 events
#   Total events from file: 7827
#
# Processing: 20250801_071756_113164_20250318 - Firearm audit worksheet - MK - v1.xlsx
#   Found 3 sheets
#     Sheet 'Issues by branch': No valid data found
#     Sheet 'List of all weapons (3-18)': 20296 events
#     Sheet 'List of WV weapons to sell': 324 events
#   Total events from file: 20620
#
# Processing: 20250801_071756_127041_CE Audit 041425.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (9)': 2879 events
#   Total events from file: 2897
#
# Processing: 20250801_071756_176977_CE Audit 040825 0800hrs.xlsx
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (6)': 2877 events
#   Total events from file: 2895
#
# Processing: 20250801_071756_287126_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
#   Found 4 sheets
#     Sheet 'Detail1': No valid data found
#     Sheet 'Sheet3': No valid data found
#     Sheet 'data': No valid data found
#     Sheet 'Sheet1': 19587 events
#   Total events from file: 19587
#
# Processing: 20250801_071756_310477_CE Inventory 1015 032625.xlsx
#   Found 18 sheets
# ...
#   Found 2 sheets
#     Sheet 'Sheet1': 18 events
#     Sheet 'regionInventoryReport (12)': 2878 events
#   Total events from file: 2896
#
# Processing: 20250801_071812_952917_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
#   Found 4 sheets
#     Sheet '2025.03.19': 30 events
#     Sheet '2025.03.28': 170 events
#     Sheet '2025.04.07': 4 events
#     Sheet 'AllAUS': 19603 events
#   Total events from file: 19807
#
# Processing: P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2359 events
#   Total events from file: 2359
#
# Processing: 032415 443 pm Mike File.xls
#   Found 13 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'MVR': No valid data found
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#   Total events from file: 120
#
# Processing: ussa firearms 1_15_2019 JCG.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2184 events
#   Total events from file: 2184
#
# Processing: CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
#   Found 9 sheets
#     Sheet 'Fleet Inspection': 49 events
#     Sheet 'Driver Checks': No valid data found
#     Sheet 'Applicant Tracking': No valid data found
#     Sheet 'Armed Guard Review': 35 events
#     Sheet 'Firearm Inventory': No valid data found
#     Sheet 'Firearm Physical Count': 81 events
#     Sheet 'Site Inspections-1': No valid data found
#     Sheet 'Site Inspection-2': No valid data found
#     Sheet 'Safety Inspections': No valid data found
#   Total events from file: 165
#
# Processing: Certified Parts Order form ALLIED UNIVERSAL 1.9.2023.xls
#   Found 1 sheets
#     Sheet 'FRM-72-26': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071751_267318_032415 443 pm Mike File (5).xls
#   Found 13 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'MVR': No valid data found
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#   Total events from file: 120
#
# Processing: 20250801_071752_285564_Mike File.xls
#   Found 14 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Fleet': 47 events
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#     Sheet 'Payroll Adjustments': No valid data found
#   Total events from file: 167
#
# Processing: 20250801_071752_485427_032615 Mike File (7).xls
#   Found 14 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Fleet': 47 events
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#     Sheet 'Payroll Adjustments': No valid data found
#   Total events from file: 167
#
# Processing: 20250801_071753_951034_Mike File.xls
#   Found 13 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Fleet': No valid data found
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#   Total events from file: 120
#
# Processing: 20250801_071753_974456_032515 1216 pm Mike File (6).xls
#   Found 13 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Fleet': 47 events
#     Sheet 'Armed Guard': 29 events
#     Sheet 'Officer Hours Review': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Proof Hours Review': 1 events
#     Sheet 'Client Invoice Hours': 13 events
#     Sheet 'Client File Review': No valid data found
#     Sheet 'Approved Contract Bill Rate': No valid data found
#     Sheet 'Firearm Inventory': 53 events
#     Sheet 'Physical Count': 24 events
#   Total events from file: 167
#
# Processing: 20250801_071754_587994_ussa firearms 1_15_2019 JCG.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071754_772439_USSA Firearms.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2354 events
#   Total events from file: 2354
#
# Processing: 20250801_071756_922110_P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2354 events
#   Total events from file: 2354
#
# Processing: 20250801_071757_499079_USSA Firearms.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2354 events
#   Total events from file: 2354
#
# Processing: 20250801_071757_561930_CS0418310 - Program V Worksheets - CLIENT BILLING.xls
#   Found 3 sheets
#     Sheet 'Client Invoice Hours Review': 26 events
#     Sheet 'Sheet1': 26 events
#     Sheet 'Approved Contract Bill Rates': No valid data found
#   Total events from file: 52
#
# Processing: 20250801_071757_562476_CS0418310 - Program IV Worksheets - PAYROLL.xls
#   Found 6 sheets
#     Sheet 'Payroll Record Retention': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Officer Hours Review': 40 events
#     Sheet 'S.A.R. Hours Review': 2 events
#     Sheet 'Excessive Hours': No valid data found
#     Sheet 'Payroll Adjustments': No valid data found
#   Total events from file: 42
#
# Processing: 20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
#   Found 7 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Sheet1': No valid data found
#     Sheet 'Past Postive HR and Training': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Required Postings': No valid data found
#     Sheet 'Document Security': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
#   Found 9 sheets
#     Sheet 'Fleet Inspection': 49 events
#     Sheet 'Driver Checks': No valid data found
#     Sheet 'Applicant Tracking': No valid data found
#     Sheet 'Armed Guard Review': 35 events
#     Sheet 'Firearm Inventory': No valid data found
#     Sheet 'Firearm Physical Count': 81 events
#     Sheet 'Site Inspections-1': No valid data found
#     Sheet 'Site Inspection-2': No valid data found
#     Sheet 'Safety Inspections': No valid data found
#   Total events from file: 165
#
# Processing: 20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
#   Found 5 sheets
#     Sheet 'Cilent File Review': No valid data found
#     Sheet 'Gen Liability-Claims Review': No valid data found
#     Sheet 'License Expiration Review': No valid data found
#     Sheet 'Officer-Mgmt Training': No valid data found
#     Sheet 'Site Training Review': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071757_565094_CS0418310 - Audit Score Sheet.xls
#   Found 3 sheets
#     Sheet 'Summary': No valid data found
#     Sheet 'Grading Sheet': No valid data found
#     Sheet 'Final Score': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071757_566802_CS0418310 - Audit Report Card.xls
#   Found 3 sheets
#     Sheet 'Sheet1': 39 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 39
#
# Processing: 20250801_071758_833013_CS0418310 - Program V Worksheets - CLIENT BILLING.xls
#   Found 3 sheets
#     Sheet 'Client Invoice Hours Review': 26 events
#     Sheet 'Sheet1': 26 events
#     Sheet 'Approved Contract Bill Rates': No valid data found
#   Total events from file: 52
#
# Processing: 20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
#   Found 6 sheets
#     Sheet 'Payroll Record Retention': No valid data found
#     Sheet 'Client Hours Review': No valid data found
#     Sheet 'Officer Hours Review': 40 events
#     Sheet 'S.A.R. Hours Review': 2 events
#     Sheet 'Excessive Hours': No valid data found
#     Sheet 'Payroll Adjustments': No valid data found
#   Total events from file: 42
#
# Processing: 20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
#   Found 7 sheets
#     Sheet 'Files Review': No valid data found
#     Sheet 'I-9 Separate Files Review': No valid data found
#     Sheet 'Sheet1': No valid data found
#     Sheet 'Past Postive HR and Training': No valid data found
#     Sheet 'Terminations': No valid data found
#     Sheet 'Required Postings': No valid data found
#     Sheet 'Document Security': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
#   Found 9 sheets
#     Sheet 'Fleet Inspection': 49 events
#     Sheet 'Driver Checks': No valid data found
#     Sheet 'Applicant Tracking': No valid data found
#     Sheet 'Armed Guard Review': 35 events
#     Sheet 'Firearm Inventory': No valid data found
#     Sheet 'Firearm Physical Count': 81 events
#     Sheet 'Site Inspections-1': No valid data found
#     Sheet 'Site Inspection-2': No valid data found
#     Sheet 'Safety Inspections': No valid data found
#   Total events from file: 165
#
# Processing: 20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
#   Found 5 sheets
#     Sheet 'Cilent File Review': No valid data found
#     Sheet 'Gen Liability-Claims Review': No valid data found
#     Sheet 'License Expiration Review': No valid data found
#     Sheet 'Officer-Mgmt Training': No valid data found
#     Sheet 'Site Training Review': No valid data found
#   Total events from file: 0
#
# Processing: 20250801_071758_837515_CS0418310 - Audit Report Card.xls
#   Found 3 sheets
#     Sheet 'Sheet1': 39 events
#     Sheet 'Sheet2': No valid data found
#     Sheet 'Sheet3': No valid data found
#   Total events from file: 39
#
# Processing: 20250801_071758_845772_P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2359 events
#   Total events from file: 2359
#
# Processing: 20250801_071759_585020_ussa firearms 1_15_2019 JCG.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2184 events
#   Total events from file: 2184
#
# Processing: 20250801_071759_594453_P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2359 events
#   Total events from file: 2359
#
# Processing: 20250801_071801_573614_P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2359 events
#   Total events from file: 2359
#
# Processing: 20250801_071801_585137_P3 list for AU - company owned.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2354 events
#   Total events from file: 2354
#
# Processing: 20250801_071811_621520_USSA Firearms.xls
#   Found 1 sheets
#     Sheet 'Company owned': 2354 events
#   Total events from file: 2354
#
# ==================================================
# EXCEL PROCESSING SUMMARY
# ==================================================
# Files processed: 378
# Files skipped: 0
# Sheets processed: 1584/1584
# Total events extracted: 3692548
# Unique serial numbers: 58065
#
# Event types found:
#   Inventory: 2085576
#   Employee Assignment: 1016724
#   Event: 118705
#   ACQ_DATE: 55269
#   DSP_DATE: 53847
#   Inspection: 52256
#   Employee_has_been_issued_2024_updated: 47298
#   Inferred Event: 45769
#   Acquired: 30386
#   MaxUpdate: 28918
#   Effective: 28916
#   Assigned: 28916
#   Assignment: 27027
#   Acquire: 22989
#   Accepted: 13932
#   Last Status Time/: 9414
#   .1: 6093
#   Previous   Inspection / Other Data: 4530
#   Disposition: 2781
#   API Delivered  Time: 2683
#   Return: 2553
#   UPDATE 02/26/2025 ATF AUDIT - Allied Universal Security Services - WPB Branch S3180: 1880
#   Upload: 1758
#   dis date: 909
#   __Inspection: 833
#   Audit date 2024: 700
#   Acquired (Asset): 519
#   Added (System): 519
#   Audit date: 252
#   DATE: 184
#   Update info in Orchid (stolen): 135
#   DATE VALIDATED: 81
#   Recent Photo (): 53
#   Start: 53
#   Location, condition, or other remarks.  If issued to an idividual, then reflect presence  a signed Delegation  Authority form and date: 35
#   Hello FIN Team, Please note the following 2 points in BLUE I am in need  help with ... Serial #'s Indiana Branch Office has never had these 8 serial #'s starting with P, R, V and need these removed from inventory (See attached email from 2/26) PLX900 PLX906 PTD886 PVL586 RNF684 V1919623 v1962327 v1963325 Serial # Needs Removed as was reported stolen(see attached email from 2/25/25) BUNH779 - Reported stolen NOTE: BUNH800 - was removed without issue from initial request so just waiting on BUNH 779 to also be removed Serial # Needs Reassigned to Chicago South, IL Branch Office (see attached email from 06/15/2022) BCSH894 - Needs transferred Weapon was transferred on 06/15/2022 from Indiana to Illinois due to Armed Job being absorbed by Illinois Branch Officer Entry Issue The following 2 Officers are not pulling in the system for us to assign weapons to ..... Onesiphore Horus Finagnon 9783522 Scott Rushton 535919 Note: I know we can do this correctly as there was a 3rd Officer (Brandon Chenault) and we successfully added him, and he pulled in the data just fine this morning. What are we missing with the above two listed ficers? System Issue - FYI only Today I revalidated all my serial #'s and found 16 that were previously entered in the system as Indiana Office Safe but today, those individual and random serial 3's dropped out  my BIN and were not assigned. To fix this, I unassigned and reassigned the BIN and that did work. ALL IS GOOD NOW.... i Just wanted to report this up so you knew about it. Thank you for all your assistance with the above, I appreciate your valuable time. William (Bill) Miller Project Manager Indiana Allied Universal 8777 Purdue Rd | Suite #300 | Indianapolis, IN 46268 C: 317.650.3621 | william.miller@aus.com: 20
#   Last LSG Notes /Time: 17
#   Update Serial #: 6
#   Update Model: 6
#   Update Make: 6
#
# Serial numbers with multiple events: 56781
# Top 5 serial numbers by event count:
#   316-08588: 388 events
#   314-94876: 388 events
#   316-06794: 388 events
#   316-05264: 388 events
#   314-94888: 388 events
# Saved 3692548 records to reports/excel_events_standardized.csv
# Saved 3691264 records to reports/excel_multi_event_standardized.csv
# Saved multi-event records: 3691264 records
#
# ✓ Excel processing complete! 3692548 standardized records created.
# Files saved:
#   - reports/excel_events_standardized.csv (all events)
#   - reports/excel_multi_event_standardized.csv (multi-event serials)

# %%
# Cell 8: Serial Number Character Analysis
# This cell analyzes all CSV and Excel files to find non-alphanumeric characters in serial numbers and their positions

import re
import pandas as pd
from collections import defaultdict


def analyze_serial_number_characters(discovered_files):
    """
    Analyze serial numbers in all CSV and Excel files to identify non-alphanumeric characters and their positions.
    """
    print("ANALYZING SERIAL NUMBERS FOR NON-ALPHANUMERIC CHARACTERS")
    print("=" * 70)

    # Collect all files to analyze
    csv_files = discovered_files.get("CSV Files", [])
    xlsx_files = discovered_files.get("Excel Files (xlsx)", [])
    xls_files = discovered_files.get("Excel Files (xls)", [])

    all_files = csv_files + xlsx_files + xls_files
    print(
        f"Total files to analyze: {len(all_files)} ({len(csv_files)} CSV, {len(xlsx_files)} XLSX, {len(xls_files)} XLS)"
    )

    # Dictionary to store character analysis results
    char_analysis = defaultdict(
        lambda: {"count": 0, "positions": defaultdict(int), "files": set()}
    )
    total_serials_processed = 0
    files_with_issues = set()
    failed_files = []

    # Process CSV files
    for file_path in csv_files:
        try:
            # Use our preprocessing function to handle misaligned rows
            df_result = preprocess_csv_for_alignment(file_path)

            # Check if preprocessing returned a DataFrame or an error message
            if isinstance(df_result, str):
                # Preprocessing returned an error message
                print(f"Skipping CSV file {file_path}: {df_result}")
                failed_files.append(file_path)
                continue
            elif not isinstance(df_result, pd.DataFrame):
                # Preprocessing returned something unexpected
                print(
                    f"Skipping CSV file {file_path}: Unexpected return type {type(df_result)}"
                )
                failed_files.append(file_path)
                continue
            elif df_result.empty:
                # Preprocessing returned an empty DataFrame
                print(
                    f"Skipping CSV file {file_path}: Empty DataFrame after preprocessing"
                )
                failed_files.append(file_path)
                continue

            df = df_result

            if "Serial Number" in df.columns:
                serials = df["Serial Number"].dropna().astype(str)
                analyze_serials_in_series(
                    serials, file_path, char_analysis, files_with_issues
                )
                total_serials_processed += len(serials)
            else:
                # Try to find alternative serial number column names
                serial_col = find_serial_column(df)
                if serial_col:
                    serials = df[serial_col].dropna().astype(str)
                    analyze_serials_in_series(
                        serials, file_path, char_analysis, files_with_issues
                    )
                    total_serials_processed += len(serials)
                else:
                    print(
                        f"Skipping CSV file {file_path}: No serial number column found"
                    )
        except Exception as e:
            print(f"Error processing CSV file {file_path}: {str(e)}")
            failed_files.append(file_path)

    # Process Excel files
    for file_path in xlsx_files + xls_files:
        try:
            # Determine engine based on file extension
            engine = "openpyxl" if file_path.endswith(".xlsx") else "xlrd"

            # Load Excel file
            xls = pd.ExcelFile(file_path, engine=engine)

            # Process each sheet
            for sheet_name in xls.sheet_names:
                try:
                    df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)

                    if df.empty:
                        print(
                            f"Skipping sheet {sheet_name} in {file_path}: Empty sheet"
                        )
                        continue

                    if "Serial Number" in df.columns:
                        serials = df["Serial Number"].dropna().astype(str)
                        analyze_serials_in_series(
                            serials,
                            f"{file_path} [{sheet_name}]",
                            char_analysis,
                            files_with_issues,
                        )
                        total_serials_processed += len(serials)
                    else:
                        # Try to find alternative serial number column names
                        serial_col = find_serial_column(df)
                        if serial_col:
                            serials = df[serial_col].dropna().astype(str)
                            analyze_serials_in_series(
                                serials,
                                f"{file_path} [{sheet_name}]",
                                char_analysis,
                                files_with_issues,
                            )
                            total_serials_processed += len(serials)
                        else:
                            print(
                                f"No serial number column found in sheet {sheet_name} of {file_path}"
                            )
                except Exception as e:
                    print(
                        f"Error processing sheet {sheet_name} in {file_path}: {str(e)}"
                    )
        except Exception as e:
            print(f"Error processing Excel file {file_path}: {str(e)}")
            failed_files.append(file_path)

    # Report results
    print(f"\nANALYSIS COMPLETE")
    print("=" * 70)
    print(f"Total serial numbers processed: {total_serials_processed}")
    print(
        f"Files with non-alphanumeric characters in serial numbers: {len(files_with_issues)}"
    )
    print(f"Files that failed to process: {len(failed_files)}")

    if failed_files:
        print(f"\nFAILED FILES:")
        print("-" * 30)
        for file in failed_files[:10]:  # Show first 10
            print(f"  {file}")
        if len(failed_files) > 10:
            print(f"  ... and {len(failed_files) - 10} more")

    if char_analysis:
        print(f"\nNON-ALPHANUMERIC CHARACTERS FOUND:")
        print("-" * 40)

        # Sort by frequency
        sorted_chars = sorted(
            char_analysis.items(), key=lambda x: x[1]["count"], reverse=True
        )

        for char, data in sorted_chars:
            print(f"Character '{char}' (ASCII: {ord(char)})")
            print(f"  Total occurrences: {data['count']}")
            print(f"  Found in files: {len(data['files'])}")

            # Show position distribution
            sorted_positions = sorted(data["positions"].items())
            position_info = ", ".join(
                [f"pos {pos}: {count}" for pos, count in sorted_positions[:10]]
            )
            if len(sorted_positions) > 10:
                position_info += f", ... ({len(sorted_positions) - 10} more positions)"
            print(f"  Position distribution: {position_info}")
            print()

        # Show top 10 files with most issues
        file_issue_counts = defaultdict(int)
        for char_data in char_analysis.values():
            for file in char_data["files"]:
                file_issue_counts[file] += 1

        if file_issue_counts:
            print("TOP FILES WITH MOST NON-ALPHANUMERIC CHARACTERS IN SERIAL NUMBERS:")
            print("-" * 60)
            sorted_files = sorted(
                file_issue_counts.items(), key=lambda x: x[1], reverse=True
            )
            for file, count in sorted_files[:10]:
                print(f"  {file}: {count} different characters")
    else:
        print("\nNo non-alphanumeric characters found in serial numbers!")

    return char_analysis


def analyze_serials_in_series(
    serials, file_identifier, char_analysis, files_with_issues
):
    """
    Analyze a series of serial numbers for non-alphanumeric characters.
    """
    for serial in serials:
        # Find all non-alphanumeric characters and their positions
        for i, char in enumerate(serial):
            if not char.isalnum():
                char_analysis[char]["count"] += 1
                char_analysis[char]["positions"][i] += 1
                char_analysis[char]["files"].add(file_identifier)
                files_with_issues.add(file_identifier)


def find_serial_column(df):
    """
    Try to find a column that might contain serial numbers based on naming patterns.
    """
    possible_names = [
        "serial",
        "sn",
        "s/n",
        "serial#",
        "serial number",
        "serial_no",
        "serial_num",
        "firearm serial",
        "gun serial",
    ]

    for col in df.columns:
        col_lower = str(col).lower()
        for name in possible_names:
            if name in col_lower:
                return col
    return None


# Run the analysis if we have discovered files
if "discovered_files" in globals() and discovered_files:
    serial_char_analysis = analyze_serial_number_characters(discovered_files)
else:
    print("No discovered_files found. Run file discovery first.")
# Out:
# ANALYZING SERIAL NUMBERS FOR NON-ALPHANUMERIC CHARACTERS
# ======================================================================
# Total files to analyze: 391 (13 CSV, 345 XLSX, 33 XLS)
# Skipping CSV file data/AUS Weapons List.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmps1t6eefz.csv
# Skipping CSV file temp_attachments/20250801_071752_173946_regionInventoryReport (36).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmptqh967hn.csv
# Skipping CSV file temp_attachments/20250801_071753_217501_AUS Weapons List.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmp6rf667ni.csv
# Skipping CSV file temp_attachments/20250801_071753_391257_regionInventoryReport (7).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpz693caow.csv
# Skipping CSV file temp_attachments/20250801_071754_795836_Bin Report.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpnmtgo3e3.csv
# Skipping CSV file temp_attachments/20250801_071756_477557_regionInventoryReport (2).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpxuqv22tu.csv
# Skipping CSV file temp_attachments/20250801_071756_913944_branchAssignmentReport (4).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmphe7kl4ae.csv
# Skipping CSV file temp_attachments/20250801_071757_741562_All AUS 3-21-25 1600EST.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmp7qkc4l_9.csv
# Skipping CSV file temp_attachments/20250801_071801_013951_regionInventoryReport (TC9600-TC9604).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpexprb8ar.csv
# Skipping CSV file temp_attachments/20250801_071809_474678_regionInventoryReport (35).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpd7y6zy20.csv
# Skipping CSV file temp_attachments/20250801_071809_586470_regionInventoryReport (8).csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmpqa0f9lct.csv
# Skipping CSV file temp_attachments/20250801_071811_522550_AUS Weapons List.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmp5i50ry4y.csv
# Skipping CSV file temp_attachments/20250801_071812_347446_All AUS 3-14-25 2000EST.csv: /var/folders/94/jlyp8h5n6tg_81hstwdbmqqh0000gn/T/tmp4u4q5h_j.csv
# No serial number column found in sheet Sheet1 of data/2022 Weapon Inventory Form.xlsx
# No serial number column found in sheet Sheet2 of data/2022 Weapon Inventory Form.xlsx
# No serial number column found in sheet Sheet3 of data/2022 Weapon Inventory Form.xlsx
# No serial number column found in sheet Overview Report of data/Murray Weapons (2).xlsx
# No serial number column found in sheet Transfer Weapons of data/Murray Weapons (2).xlsx
# No serial number column found in sheet Branch Addresses of data/Murray Weapons (2).xlsx
# No serial number column found in sheet STATISTICS of data/Master Certification List MAC45.xlsx
# No serial number column found in sheet LEGEND of data/Master Certification List MAC45.xlsx
# No serial number column found in sheet Sheet1 of data/4-29-2021 IN-SAFE 4144 Weapons Inventory.xlsx
# No serial number column found in sheet Combined A&D of data/Dallas Workbook.xlsx
# No serial number column found in sheet Sheet2 of data/Central AUS Inventory.xlsx
# No serial number column found in sheet Sheet1 of data/AUS FFL Workbook 06_02_22 JCG.xlsx
# No serial number column found in sheet Sheet2 of data/AUS FFL Workbook 06_02_22 JCG.xlsx
# Skipping sheet Sheet3 in data/AUS FFL Workbook 06_02_22 JCG.xlsx: Empty sheet
# No serial number column found in sheet Sheet1 of data/ABSS FFL A&D Log 06_19_2019 with location.xlsx
# No serial number column found in sheet Sheet2 of data/ABSS FFL A&D Log 06_19_2019 with location.xlsx
# Skipping sheet Sheet3 in data/ABSS FFL A&D Log 06_19_2019 with location.xlsx: Empty sheet
# No serial number column found in sheet Company Owned of data/Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of data/Weapons Database - Area 16.xlsx
# No serial number column found in sheet Sheet1 of data/2021 Central Inventory Form.xlsx
# Skipping sheet Sheet4 in data/2021 Central Inventory Form.xlsx: Empty sheet
# No serial number column found in sheet Sheet2 of data/2021 Central Inventory Form.xlsx
# No serial number column found in sheet Sheet3 of data/2021 Central Inventory Form.xlsx
# No serial number column found in sheet Dashboard of data/AUS-USSA Firearm Inventory.xlsx
# Skipping sheet NE in data/AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet NW in data/AUS-USSA Firearm Inventory.xlsx: Empty sheet
# No serial number column found in sheet Source Data of data/AUS-USSA Firearm Inventory.xlsx
# No serial number column found in sheet Issues by branch of data/Copy of 20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet Open FIM - SW of data/Copy of 20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet Field says not in Orchid of data/Copy of 20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet AUS A&D Log of data/New AUS FFL A&D Log 07_03_2019 with location.xlsx
# Skipping sheet Sheet1 in data/New AUS FFL A&D Log 07_03_2019 with location.xlsx: Empty sheet
# No serial number column found in sheet Dashboard of data/AUS-USSA Firearm Workbook.xlsx
# Skipping sheet NE in data/AUS-USSA Firearm Workbook.xlsx: Empty sheet
# No serial number column found in sheet Source Data of data/AUS-USSA Firearm Workbook.xlsx
# No serial number column found in sheet Sheet1 of data/Expected FA.xlsx
# No serial number column found in sheet Sheet2 of data/Expected FA.xlsx
# Skipping sheet Sheet3 in data/Expected FA.xlsx: Empty sheet
# No serial number column found in sheet regionInventoryReport (3) of data/Weapons comparison v 1.xlsx
# No serial number column found in sheet Possible matches to work on of data/Weapons comparison v 1.xlsx
# No serial number column found in sheet Sheet1 of data/FFL Workbook 6_3_20 to ND.xlsx
# No serial number column found in sheet Sheet2 of data/FFL Workbook 6_3_20 to ND.xlsx
# Skipping sheet Sheet3 in data/FFL Workbook 6_3_20 to ND.xlsx: Empty sheet
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071751_159868_CE Deltas 031425.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071751_207665_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071751_207665_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071751_207665_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071751_246630_2021 Central Inventory Form.xlsx
# Skipping sheet Sheet4 in temp_attachments/20250801_071751_246630_2021 Central Inventory Form.xlsx: Empty sheet
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071751_246630_2021 Central Inventory Form.xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071751_246630_2021 Central Inventory Form.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071751_248635_Expected FA.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071751_248635_Expected FA.xlsx
# Skipping sheet Sheet3 in temp_attachments/20250801_071751_248635_Expected FA.xlsx: Empty sheet
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071751_262027_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071751_850275_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071751_850275_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071751_850275_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071751_879868_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071751_879868_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071751_879868_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071751_901897_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Company Owned of temp_attachments/20250801_071751_918449_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of temp_attachments/20250801_071751_918449_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071751_920857_1300 & 4144 Weapons Inventory.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071752_005293_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071752_005293_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071752_005293_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_040656_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet PIVOT of temp_attachments/20250801_071752_040656_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_063189_All AUS 3-13-25 1730.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071752_063189_All AUS 3-13-25 1730.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_106410_CE Audit 042925 EoD.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071752_143108_AUS-USSA Firearm Workbook.xlsx
# Skipping sheet NE in temp_attachments/20250801_071752_143108_AUS-USSA Firearm Workbook.xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071752_143108_AUS-USSA Firearm Workbook.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071752_201059_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071752_201059_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071752_201059_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_281286_CE Audit 040825 0800hrs.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071752_300889_Copy of AUS-USSA Firearm Inventory (1) (1).xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_323648_FFL Workbook 7_11_20 to ND - Copy.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071752_323648_FFL Workbook 7_11_20 to ND - Copy.xlsx
# Skipping sheet Sheet3 in temp_attachments/20250801_071752_323648_FFL Workbook 7_11_20 to ND - Copy.xlsx: Empty sheet
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071752_350207_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071752_350207_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071752_350207_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet Issues by branch of temp_attachments/20250801_071752_409108_20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet Open FIM - SW of temp_attachments/20250801_071752_409108_20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet Field says not in Orchid of temp_attachments/20250801_071752_409108_20250320 - Firearm audit worksheet.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_452383_regionInventoryReport (45) 1700 031225.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx
# Skipping sheet CE in temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071752_479071_AUS-USSA Firearm Inventory.xlsx
# No serial number column found in sheet SOURCE DATA of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet OK of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet Duplicate Open SNs of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet Issues with Region Branch of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet IGNORE of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071752_572246_AUS FFL Workbook 06_20_22 MER v2.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071752_637113_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071752_637113_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071752_637113_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_648782_CE Audit 031425.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_702235_AUS FFL Workbook 06_02_22 JCG.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071752_702235_AUS FFL Workbook 06_02_22 JCG.xlsx
# Skipping sheet Sheet3 in temp_attachments/20250801_071752_702235_AUS FFL Workbook 06_02_22 JCG.xlsx: Empty sheet
# Skipping sheet Master in temp_attachments/20250801_071752_708856_AUS Weapons Audit (3).xlsx: Empty sheet
# No serial number column found in sheet DATA Sheet of temp_attachments/20250801_071752_708856_AUS Weapons Audit (3).xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071752_789552_CE Deltas 031425.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071752_822438_CE Audit 042825 6pm.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071753_031023_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071753_031023_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071753_031023_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_045027_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet PIVOT of temp_attachments/20250801_071753_045027_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071753_055487_AUS-USSA Firearm Inventory (1) (1).xlsx
# No serial number column found in sheet Company Owned of temp_attachments/20250801_071753_104308_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of temp_attachments/20250801_071753_104308_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_122485_FFL Workbook 6_3_20 to ND.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071753_122485_FFL Workbook 6_3_20 to ND.xlsx
# Skipping sheet Sheet3 in temp_attachments/20250801_071753_122485_FFL Workbook 6_3_20 to ND.xlsx: Empty sheet
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx
# Skipping sheet CE in temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071753_141122_AUS-USSA Firearm Inventory.xlsx
# No serial number column found in sheet Company Owned of temp_attachments/20250801_071753_250489_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of temp_attachments/20250801_071753_250489_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_266732_regionInventoryReport (19) 030625 EOD.xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071753_266732_regionInventoryReport (19) 030625 EOD.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_273184_CE Audit 041625 - Caileen Copy .xlsx
# No serial number column found in sheet Detail2 of temp_attachments/20250801_071753_283656_regionInventoryReport (45) 1700 031225.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_283656_regionInventoryReport (45) 1700 031225.xlsx
# No serial number column found in sheet data of temp_attachments/20250801_071753_398649_Active Licenses (1).xlsx
# No serial number column found in sheet data of temp_attachments/20250801_071753_409132_Expired Licenses (1).xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071753_430518_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071753_430518_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071753_430518_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071753_459051_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071753_459051_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071753_459051_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_485725_CE Audit 042825 6pm.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_518245_CE Audit 042925 EoD.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_520078_CE Audit 042825 6pm.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071753_554873_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071753_554873_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071753_554873_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Company Owned of temp_attachments/20250801_071753_576711_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of temp_attachments/20250801_071753_576711_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_641734_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet PIVOT of temp_attachments/20250801_071753_641734_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet Safe of temp_attachments/20250801_071753_860733_Equipment Inventory Previous.xlsx
# No serial number column found in sheet Uniforms of temp_attachments/20250801_071753_860733_Equipment Inventory Previous.xlsx
# No serial number column found in sheet Safe of temp_attachments/20250801_071753_891292_Equipment Inventory Current 2025.xlsx
# No serial number column found in sheet Uniforms of temp_attachments/20250801_071753_891292_Equipment Inventory Current 2025.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071753_938809_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071753_938809_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071753_938809_Firearms Photo Log ATF.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_948167_4-29-2021 IN-SAFE 4144 Weapons Inventory.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx
# Skipping sheet CE in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071753_968884_Copy of AUS-USSA Firearm Inventory 2.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071753_991884_regionInventoryReport (14).xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071754_028534_Central AUS Inventory.xlsx
# No serial number column found in sheet Combined A&D of temp_attachments/20250801_071754_029449_Dallas Workbook.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_033190_ABSS FFL A&D Log 06_19_2019 with location.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071754_033190_ABSS FFL A&D Log 06_19_2019 with location.xlsx
# Skipping sheet Sheet3 in temp_attachments/20250801_071754_033190_ABSS FFL A&D Log 06_19_2019 with location.xlsx: Empty sheet
# No serial number column found in sheet AUS A&D Log of temp_attachments/20250801_071754_036315_New AUS FFL A&D Log 07_03_2019 with location.xlsx
# Skipping sheet Sheet1 in temp_attachments/20250801_071754_036315_New AUS FFL A&D Log 07_03_2019 with location.xlsx: Empty sheet
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071754_133364_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071754_133364_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071754_133364_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_148234_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet PIVOT of temp_attachments/20250801_071754_148234_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071754_179712_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071754_179712_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071754_179712_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_205973_CE Audit 042925 EoD.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_207752_CE Audit 042825 6pm.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071754_247415_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071754_247415_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071754_247415_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071754_328659_Firearms Reported - Not in A&D Rev. 4-9-2025 RB assigned V2.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_355038_regionInventoryReport (19) 030625 EOD.xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071754_355038_regionInventoryReport (19) 030625 EOD.xlsx
# No serial number column found in sheet Detail1 of temp_attachments/20250801_071754_493854_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071754_493854_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet data of temp_attachments/20250801_071754_493854_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_493854_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_517949_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Deltas of temp_attachments/20250801_071754_517949_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Serial Numbers -3701 Remaining of temp_attachments/20250801_071754_546297_FIM Tickets 2025.03.25 with Outstanding Serial Numbers.xlsx
# No serial number column found in sheet CONFIDENTIAL - Subset of 3701 of temp_attachments/20250801_071754_546297_FIM Tickets 2025.03.25 with Outstanding Serial Numbers.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071754_565881_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071754_578779_AUS-USSA Firearm Inventory (1) (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071754_601523_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071754_617450_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071754_633079_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_648661_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet PIVOT of temp_attachments/20250801_071754_648661_regionInventoryReport (28)1200 031025.xlsx
# No serial number column found in sheet Company Owned of temp_attachments/20250801_071754_673093_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Personally Owned of temp_attachments/20250801_071754_673093_Weapons Database - Area 16.xlsx
# No serial number column found in sheet Master File of temp_attachments/20250801_071754_771090_Copy of Copy of Project Vinson weapons inventory (002).xlsx
# No serial number column found in sheet Inspected of temp_attachments/20250801_071754_771090_Copy of Copy of Project Vinson weapons inventory (002).xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071754_771620_Yall 3_3_2017.xlsx
# No serial number column found in sheet Remaining Mercury SNs of temp_attachments/20250801_071754_944292_Mercury Campaign SN Inputs  - SNs Unassigned v05122025.xlsx
# No serial number column found in sheet Burn Down List of temp_attachments/20250801_071754_944292_Mercury Campaign SN Inputs  - SNs Unassigned v05122025.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071755_005046_Firearms Reported - Not in A&D Rev. 4-18-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071755_005046_Firearms Reported - Not in A&D Rev. 4-18-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071755_005046_Firearms Reported - Not in A&D Rev. 4-18-25.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071755_605217_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071755_605217_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071755_605217_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071755_640710_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071755_640710_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071755_640710_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071755_692956_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Deltas of temp_attachments/20250801_071755_692956_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071755_706173_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071755_719528_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071755_734869_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071755_750871_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx
# No serial number column found in sheet Detail2 of temp_attachments/20250801_071755_864743_regionInventoryReport (45) 1700 031225.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071755_864743_regionInventoryReport (45) 1700 031225.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071755_929120_CE Audit 042825 6pm.xlsx
# No serial number column found in sheet 2025.03.19 of temp_attachments/20250801_071755_973955_Firearms Reported - Not in A&D Rev. 4-15-25.xlsx
# No serial number column found in sheet 2025.04.07 of temp_attachments/20250801_071755_973955_Firearms Reported - Not in A&D Rev. 4-15-25.xlsx
# No serial number column found in sheet 2025.03.28 of temp_attachments/20250801_071755_973955_Firearms Reported - Not in A&D Rev. 4-15-25.xlsx
# No serial number column found in sheet Sheet2 of temp_attachments/20250801_071755_981333_AUS Bundle 5 61625.xlsx
# No serial number column found in sheet Sheet4 of temp_attachments/20250801_071756_054846_Mercury Campaign SN Inputs  - SNs Unassigned v05082025.xlsx
# No serial number column found in sheet Issues by branch of temp_attachments/20250801_071756_113164_20250318 - Firearm audit worksheet - MK - v1.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071756_127041_CE Audit 041425.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071756_176977_CE Audit 040825 0800hrs.xlsx
# No serial number column found in sheet Detail1 of temp_attachments/20250801_071756_287126_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet3 of temp_attachments/20250801_071756_287126_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet data of temp_attachments/20250801_071756_287126_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071756_287126_National Active Licenses VS Orchid Issued 3-25-2025.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071756_310477_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Deltas of temp_attachments/20250801_071756_310477_CE Inventory 1015 032625.xlsx
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071756_313463_USAA Dallas Weapons.xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071756_325681_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SE in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet SW in temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# No serial number column found in sheet Source Data of temp_attachments/20250801_071756_340918_AUS-USSA Firearm Inventory (1).xlsx
# No serial number column found in sheet Dashboard of temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx
# Skipping sheet CE in temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MA in temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet MW in temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NE in temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# Skipping sheet NW in temp_attachments/20250801_071756_355730_AUS-USSA Firearm Inventory (1).xlsx: Empty sheet
# ...
# No serial number column found in sheet I-9 Separate Files Review of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Past Postive HR and Training of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Terminations of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Required Postings of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Document Security of temp_attachments/20250801_071757_563516_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Fleet Inspection of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Driver Checks of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Applicant Tracking of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Armed Guard Review of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Firearm Inventory of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Site Inspections-1 of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Site Inspection-2 of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Safety Inspections of temp_attachments/20250801_071757_564037_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Cilent File Review of temp_attachments/20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Gen Liability-Claims Review of temp_attachments/20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet License Expiration Review of temp_attachments/20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Officer-Mgmt Training of temp_attachments/20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Site Training Review of temp_attachments/20250801_071757_564698_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Summary of temp_attachments/20250801_071757_565094_CS0418310 - Audit Score Sheet.xls
# No serial number column found in sheet Grading Sheet of temp_attachments/20250801_071757_565094_CS0418310 - Audit Score Sheet.xls
# No serial number column found in sheet Final Score of temp_attachments/20250801_071757_565094_CS0418310 - Audit Score Sheet.xls
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071757_566802_CS0418310 - Audit Report Card.xls
# Skipping sheet Sheet2 in temp_attachments/20250801_071757_566802_CS0418310 - Audit Report Card.xls: Empty sheet
# Skipping sheet Sheet3 in temp_attachments/20250801_071757_566802_CS0418310 - Audit Report Card.xls: Empty sheet
# No serial number column found in sheet Client Invoice Hours Review of temp_attachments/20250801_071758_833013_CS0418310 - Program V Worksheets - CLIENT BILLING.xls
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071758_833013_CS0418310 - Program V Worksheets - CLIENT BILLING.xls
# No serial number column found in sheet Approved Contract Bill Rates of temp_attachments/20250801_071758_833013_CS0418310 - Program V Worksheets - CLIENT BILLING.xls
# No serial number column found in sheet Payroll Record Retention of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet Client Hours Review of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet Officer Hours Review of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet S.A.R. Hours Review of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet Excessive Hours of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet Payroll Adjustments of temp_attachments/20250801_071758_833555_CS0418310 - Program IV Worksheets - PAYROLL.xls
# No serial number column found in sheet Files Review of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet I-9 Separate Files Review of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Past Postive HR and Training of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Terminations of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Required Postings of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Document Security of temp_attachments/20250801_071758_834686_CS0418310 - Program III Worksheets - HUMAN RESOURCES.xls
# No serial number column found in sheet Fleet Inspection of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Driver Checks of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Applicant Tracking of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Armed Guard Review of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Firearm Inventory of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Site Inspections-1 of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Site Inspection-2 of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Safety Inspections of temp_attachments/20250801_071758_835190_CS0418310 - Program II Worksheets - RISK MANAGEMENT.xls
# No serial number column found in sheet Cilent File Review of temp_attachments/20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Gen Liability-Claims Review of temp_attachments/20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet License Expiration Review of temp_attachments/20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Officer-Mgmt Training of temp_attachments/20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Site Training Review of temp_attachments/20250801_071758_835849_CS0418310 - Program I Worksheets -  ADMINISTRATIVE TRAINING.xls
# No serial number column found in sheet Sheet1 of temp_attachments/20250801_071758_837515_CS0418310 - Audit Report Card.xls
# Skipping sheet Sheet2 in temp_attachments/20250801_071758_837515_CS0418310 - Audit Report Card.xls: Empty sheet
# Skipping sheet Sheet3 in temp_attachments/20250801_071758_837515_CS0418310 - Audit Report Card.xls: Empty sheet
#
# ANALYSIS COMPLETE
# ======================================================================
# Total serial numbers processed: 3095830
# Files with non-alphanumeric characters in serial numbers: 636
# Files that failed to process: 13
#
# FAILED FILES:
# ------------------------------
#   data/AUS Weapons List.csv
#   temp_attachments/20250801_071752_173946_regionInventoryReport (36).csv
#   temp_attachments/20250801_071753_217501_AUS Weapons List.csv
#   temp_attachments/20250801_071753_391257_regionInventoryReport (7).csv
#   temp_attachments/20250801_071754_795836_Bin Report.csv
#   temp_attachments/20250801_071756_477557_regionInventoryReport (2).csv
#   temp_attachments/20250801_071756_913944_branchAssignmentReport (4).csv
#   temp_attachments/20250801_071757_741562_All AUS 3-21-25 1600EST.csv
#   temp_attachments/20250801_071801_013951_regionInventoryReport (TC9600-TC9604).csv
#   temp_attachments/20250801_071809_474678_regionInventoryReport (35).csv
#   ... and 3 more
#
# NON-ALPHANUMERIC CHARACTERS FOUND:
# ----------------------------------------
# Character ' ' (ASCII: 32)
#   Total occurrences: 724277
#   Found in files: 609
#   Position distribution: pos 0: 6817, pos 1: 671, pos 2: 1864, pos 3: 4693, pos 4: 1091, pos 5: 557, pos 6: 5324, pos 7: 43947, pos 8: 54071, pos 9: 54180, ... (224 more positions)
#
# Character '-' (ASCII: 45)
#   Total occurrences: 19086
#   Found in files: 359
#   Position distribution: pos 0: 6, pos 1: 58, pos 2: 1231, pos 3: 16810, pos 4: 605, pos 5: 156, pos 6: 33, pos 7: 64, pos 8: 23, pos 9: 30, ... (20 more positions)
#
# Character ';' (ASCII: 59)
#   Total occurrences: 2430
#   Found in files: 5
#   Position distribution: pos 5: 5, pos 6: 50, pos 7: 190, pos 8: 25, pos 9: 5, pos 11: 5, pos 12: 5, pos 13: 5, pos 14: 20, pos 15: 10, ... (173 more positions)
#
# Character '.' (ASCII: 46)
#   Total occurrences: 2005
#   Found in files: 235
#   Position distribution: pos 0: 24, pos 1: 89, pos 2: 360, pos 3: 17, pos 4: 702, pos 5: 398, pos 6: 15, pos 7: 228, pos 8: 18, pos 9: 15, ... (32 more positions)
#
# Character '&' (ASCII: 38)
#   Total occurrences: 1519
#   Found in files: 214
#   Position distribution: pos 2: 3, pos 4: 10, pos 6: 6, pos 7: 109, pos 8: 6, pos 9: 669, pos 10: 367, pos 12: 334, pos 16: 3, pos 18: 6, ... (2 more positions)
#
# Character '•' (ASCII: 8226)
#   Total occurrences: 1359
#   Found in files: 118
#   Position distribution: pos 0: 1359
#
# Character '/' (ASCII: 47)
#   Total occurrences: 598
#   Found in files: 11
#   Position distribution: pos 1: 547, pos 2: 6, pos 3: 3, pos 4: 5, pos 5: 3, pos 6: 5, pos 7: 5, pos 8: 6, pos 11: 3, pos 16: 3, ... (4 more positions)
#
# Character ' ' (ASCII: 160)
#   Total occurrences: 473
#   Found in files: 12
#   Position distribution: pos 0: 50, pos 6: 14, pos 7: 155, pos 8: 44, pos 10: 42, pos 12: 42, pos 14: 42, pos 16: 42, pos 18: 42
#
# Character '*' (ASCII: 42)
#   Total occurrences: 361
#   Found in files: 134
#   Position distribution: pos 0: 339, pos 7: 10, pos 8: 12
#
# Character '
# ' (ASCII: 10)
#   Total occurrences: 192
#   Found in files: 3
#   Position distribution: pos 2: 6, pos 3: 21, pos 4: 15, pos 5: 6, pos 6: 6, pos 7: 9, pos 8: 12, pos 9: 6, pos 10: 9, pos 11: 9, ... (23 more positions)
#
# Character ',' (ASCII: 44)
#   Total occurrences: 165
#   Found in files: 17
#   Position distribution: pos 1: 3, pos 3: 6, pos 4: 6, pos 6: 6, pos 7: 51, pos 8: 21, pos 11: 3, pos 12: 3, pos 13: 3, pos 15: 3, ... (15 more positions)
#
# Character '`' (ASCII: 96)
#   Total occurrences: 159
#   Found in files: 159
#   Position distribution: pos 0: 142, pos 7: 5, pos 8: 12
#
# Character '#' (ASCII: 35)
#   Total occurrences: 98
#   Found in files: 35
#   Position distribution: pos 0: 12, pos 1: 24, pos 3: 3, pos 5: 3, pos 6: 13, pos 7: 7, pos 10: 3, pos 12: 3, pos 18: 3, pos 19: 6, ... (6 more positions)
#
# Character ''' (ASCII: 39)
#   Total occurrences: 96
#   Found in files: 3
#   Position distribution: pos 1: 3, pos 2: 12, pos 3: 24, pos 5: 42, pos 10: 3, pos 20: 3, pos 38: 3, pos 41: 3, pos 135: 3
#
# Character ')' (ASCII: 41)
#   Total occurrences: 95
#   Found in files: 23
#   Position distribution: pos 2: 5, pos 6: 12, pos 8: 3, pos 9: 12, pos 14: 12, pos 17: 3, pos 19: 9, pos 24: 3, pos 25: 3, pos 28: 3, ... (8 more positions)
#
# Character '(' (ASCII: 40)
#   Total occurrences: 95
#   Found in files: 23
#   Position distribution: pos 0: 6, pos 1: 5, pos 3: 12, pos 4: 3, pos 7: 15, pos 8: 12, pos 9: 3, pos 10: 3, pos 11: 3, pos 12: 3, ... (8 more positions)
#
# Character '?' (ASCII: 63)
#   Total occurrences: 43
#   Found in files: 16
#   Position distribution: pos 0: 3, pos 1: 3, pos 2: 3, pos 3: 6, pos 4: 3, pos 5: 3, pos 6: 3, pos 7: 3, pos 11: 13, pos 13: 3
#
# Character ':' (ASCII: 58)
#   Total occurrences: 42
#   Found in files: 21
#   Position distribution: pos 1: 5, pos 4: 3, pos 5: 13, pos 10: 3, pos 13: 9, pos 16: 6, pos 191: 3
#
# Character '\' (ASCII: 92)
#   Total occurrences: 15
#   Found in files: 3
#   Position distribution: pos 1: 15
#
# Character '+' (ASCII: 43)
#   Total occurrences: 9
#   Found in files: 3
#   Position distribution: pos 5: 3, pos 17: 3, pos 23: 3
#
# Character '_' (ASCII: 95)
#   Total occurrences: 7
#   Found in files: 4
#   Position distribution: pos 1: 6, pos 6: 1
#
# Character '×' (ASCII: 215)
#   Total occurrences: 6
#   Found in files: 3
#   Position distribution: pos 14: 3, pos 15: 3
#
# Character '	' (ASCII: 9)
#   Total occurrences: 4
#   Found in files: 2
#   Position distribution: pos 0: 2, pos 7: 2
#
# Character '@' (ASCII: 64)
#   Total occurrences: 3
#   Found in files: 3
#   Position distribution: pos 10: 3
#
# Character '=' (ASCII: 61)
#   Total occurrences: 3
#   Found in files: 3
#   Position distribution: pos 3: 3
#
# Character '!' (ASCII: 33)
#   Total occurrences: 3
#   Found in files: 3
#   Position distribution: pos 19: 3
#
# Character '|' (ASCII: 124)
#   Total occurrences: 3
#   Found in files: 3
#   Position distribution: pos 1: 3
#
# Character '>' (ASCII: 62)
#   Total occurrences: 3
#   Found in files: 3
#   Position distribution: pos 6: 3
#
# TOP FILES WITH MOST NON-ALPHANUMERIC CHARACTERS IN SERIAL NUMBERS:
# ------------------------------------------------------------
#   temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [Mercury Data]: 22 different characters
#   temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [Mercury Data]: 22 different characters
#   temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [Mercury Data]: 22 different characters
#   temp_attachments/20250801_071752_380254_Orchid Full List 03132025.xlsx [2024 DOMO Inevntory FULL]: 12 different characters
#   temp_attachments/20250801_071757_816023_2024 Weapon Inventory Breakdown Region_WinTeam Branch (1).xlsx [data]: 12 different characters
#   temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]: 11 different characters
#   temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]: 11 different characters
#   temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]: 11 different characters
#   temp_attachments/20250801_071757_656709_20250320 - Firearm audit worksheet.xlsx [List of all weapons (3-18)]: 10 different characters
#   temp_attachments/20250801_071758_793973_20250320 - Firearm audit worksheet.xlsx [List of all weapons (3-18)]: 10 different characters

# %%
# Cell 9: Serial Numbers with Non-AlphaNumeric Characters

def collect_actual_serial_examples(discovered_files, char_analysis, max_examples_per_char=1):
    """
    Collect actual serial number examples for each character from a sample of files.
    """
    from collections import defaultdict
    import random
    
    print("COLLECTING ACTUAL SERIAL NUMBER EXAMPLES")
    print("=" * 50)
    
    if not char_analysis:
        print("No character analysis data provided.")
        return {}
    
    # Get characters from actual analysis results, sorted by frequency
    sorted_chars = sorted(
        char_analysis.items(), key=lambda x: x[1]["count"], reverse=True
    )
    
    # Limit to top characters
    top_chars = sorted_chars[:15]
    
    # Dictionary to store actual examples
    actual_examples = {}
    
    # Collect a small sample of files to find examples
    csv_files = discovered_files.get("CSV Files", [])
    xlsx_files = discovered_files.get("Excel Files (xlsx)", [])
    xls_files = discovered_files.get("Excel Files (xls)", [])
    
    # Take a small sample for quick processing
    sample_files = []
    if csv_files:
        sample_files.extend(random.sample(csv_files, min(5, len(csv_files))))
    if xlsx_files:
        sample_files.extend(random.sample(xlsx_files, min(5, len(xlsx_files))))
    if xls_files:
        sample_files.extend(random.sample(xls_files, min(3, len(xls_files))))
    
    print(f"Searching for examples in {len(sample_files)} sampled files...")
    
    # Process sampled files to find actual examples
    for file_path in sample_files:
        if len([ex for ex in actual_examples.values() if ex]) >= len(top_chars) * 0.7:  # Stop if we have most examples
            break
            
        try:
            if file_path.endswith('.csv'):
                # Process CSV file
                df_result = preprocess_csv_for_alignment(file_path)
                if isinstance(df_result, pd.DataFrame) and not df_result.empty:
                    df = df_result
                    serial_col = "Serial Number" if "Serial Number" in df.columns else find_serial_column(df)
                    
                    if serial_col and serial_col in df.columns:
                        serials = df[serial_col].dropna().astype(str)
                        for serial in serials:
                            for char, _ in top_chars:
                                if char not in actual_examples and char in serial:
                                    actual_examples[char] = serial
                                    break
            else:
                # Process Excel file
                engine = "openpyxl" if file_path.endswith(".xlsx") else "xlrd"
                xls = pd.ExcelFile(file_path, engine=engine)
                
                for sheet_name in xls.sheet_names[:1]:  # First sheet only
                    try:
                        df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
                        if not df.empty:
                            serial_col = "Serial Number" if "Serial Number" in df.columns else find_serial_column(df)
                            
                            if serial_col and serial_col in df.columns:
                                serials = df[serial_col].dropna().astype(str)
                                for serial in serials:
                                    for char, _ in top_chars:
                                        if char not in actual_examples and char in serial:
                                            actual_examples[char] = serial
                                            break
                    except Exception:
                        continue
        except Exception:
            continue
    
    return actual_examples

def show_character_summary_with_actual_examples(discovered_files, char_analysis):
    """
    Show character summary with actual serial number examples on the same line.
    """
    print("SERIAL NUMBER CHARACTER ANALYSIS SUMMARY")
    print("=" * 60)
    
    if not char_analysis:
        print("No character analysis data provided.")
        return
    
    # Get characters from actual analysis results, sorted by frequency
    sorted_chars = sorted(
        char_analysis.items(), key=lambda x: x[1]["count"], reverse=True
    )
    
    # Get actual examples
    actual_examples = collect_actual_serial_examples(discovered_files, char_analysis)
    
    # Display characters with actual examples when available
    for char, data in sorted_chars[:15]:  # Top 15 characters
        char_display = repr(char) if char not in [' ', '\n', '\t'] else f"'{char}'"
        
        # Use actual example if found, otherwise use placeholder
        if char in actual_examples:
            example_display = actual_examples[char].replace('\n', '\\n').replace('\t', '\\t').replace('\r', '\\r')
            print(f"Character {char_display} (ASCII: {ord(char)}): '{example_display}'")
        else:
            # Try to get any example from the files list
            example_file = list(data['files'])[:1]
            if example_file:
                filename = example_file[0].split('/')[-1] if '[' not in example_file[0] else example_file[0].split(' [')[0].split('/')[-1]
                print(f"Character {char_display} (ASCII: {ord(char)}): example from {filename}")
            else:
                print(f"Character {char_display} (ASCII: {ord(char)}): {data['count']} occurrences in {len(data['files'])} files")
        
        # Additional details on separate lines
        print(f"  Total occurrences: {data['count']}")
        print(f"  Found in {len(data['files'])} different files")
        
        # Show some example source files
        example_files = list(data['files'])[:3]
        print(f"  Example files:")
        for file in example_files:
            print(f"    - {file}")
        if len(data['files']) > 3:
            print(f"    ... and {len(data['files']) - 3} more files")
        print()

# To execute this function:
show_character_summary_with_actual_examples(discovered_files, serial_char_analysis)
# Out:
# SERIAL NUMBER CHARACTER ANALYSIS SUMMARY
# ============================================================
# COLLECTING ACTUAL SERIAL NUMBER EXAMPLES
# ==================================================
# Searching for examples in 13 sampled files...
# Character ' ' (ASCII: 32): 'MF792.40 S&W2'
#   Total occurrences: 724277
#   Found in 609 different files
#   Example files:
#     - temp_attachments/20250801_071753_641734_regionInventoryReport (28)1200 031025.xlsx [Little Rock]
#     - temp_attachments/20250801_071801_573614_P3 list for AU - company owned.xls [Company owned]
#     - temp_attachments/20250801_071802_267948_regionInventoryReport (28)1200 031025.xlsx [Little Rock]
#     ... and 606 more files
#
# Character '-' (ASCII: 45): '310-23899'
#   Total occurrences: 19086
#   Found in 359 different files
#   Example files:
#     - temp_attachments/20250801_071801_573614_P3 list for AU - company owned.xls [Company owned]
#     - temp_attachments/20250801_071754_683926_NE Region Inv Report 7_19_23.xlsx [regionInventoryReport (1)]
#     - temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [OLD Tiger Team List v2]
#     ... and 356 more files
#
# Character ';' (ASCII: 59): example from 20250801_071754_546297_FIM Tickets 2025.03.25 with Outstanding Serial Numbers.xlsx
#   Total occurrences: 2430
#   Found in 5 different files
#   Example files:
#     - temp_attachments/20250801_071754_546297_FIM Tickets 2025.03.25 with Outstanding Serial Numbers.xlsx [FIM Tickets]
#     - temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [FIM Tickets]
#     - temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [FIM Tickets]
#     ... and 2 more files
#
# Character '.' (ASCII: 46): example from 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Total occurrences: 2005
#   Found in 235 different files
#   Example files:
#     - temp_attachments/20250801_071753_074663_All AUS 3-13-25 1730.xlsx [regionInventoryReport (51)]
#     - temp_attachments/20250801_071754_944292_Mercury Campaign SN Inputs  - SNs Unassigned v05122025.xlsx [rawdata]
#     - temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     ... and 232 more files
#
# Character '&' (ASCII: 38): example from 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Total occurrences: 1519
#   Found in 214 different files
#   Example files:
#     - temp_attachments/20250801_071753_074663_All AUS 3-13-25 1730.xlsx [regionInventoryReport (51)]
#     - temp_attachments/20250801_071754_944292_Mercury Campaign SN Inputs  - SNs Unassigned v05122025.xlsx [rawdata]
#     - temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     ... and 211 more files
#
# Character '•' (ASCII: 8226): example from 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Total occurrences: 1359
#   Found in 118 different files
#   Example files:
#     - temp_attachments/20250801_071753_074663_All AUS 3-13-25 1730.xlsx [regionInventoryReport (51)]
#     - temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     - temp_attachments/20250801_071802_298133_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     ... and 115 more files
#
# Character '/' (ASCII: 47): 'MA728/252           '
#   Total occurrences: 598
#   Found in 11 different files
#   Example files:
#     - temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]
#     - temp_attachments/20250801_071811_623328_G4S Closeout A&D.xlsx [ATF_Bound_Book_06172022]
#     - temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]
#     ... and 8 more files
#
# Character '\xa0' (ASCII: 160): example from 20250801_071759_229618_Tiger Team Research Tool v3.xlsx
#   Total occurrences: 473
#   Found in 12 different files
#   Example files:
#     - temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [2024 DOMO Inv Data]
#     - temp_attachments/20250801_071755_680586_Orchid to Orchid comparision 3-25-25.xlsx [Sheet1]
#     - temp_attachments/20250801_071805_424146_Weapons comparison v 1.xlsx [Fixed Asset master]
#     ... and 9 more files
#
# Character '*' (ASCII: 42): example from 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Total occurrences: 361
#   Found in 134 different files
#   Example files:
#     - temp_attachments/20250801_071753_074663_All AUS 3-13-25 1730.xlsx [regionInventoryReport (51)]
#     - temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     - temp_attachments/20250801_071802_298133_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     ... and 131 more files
#
# Character '
# ' (ASCII: 10): example from 20250801_071759_229618_Tiger Team Research Tool v3.xlsx
#   Total occurrences: 192
#   Found in 3 different files
#   Example files:
#     - temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [Mercury Data]
#     - temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [Mercury Data]
#     - temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [Mercury Data]
#
# Character ',' (ASCII: 44): example from 20250801_071757_631527_20250318 - Firearm audit worksheet - MK - v1.xlsx
#   Total occurrences: 165
#   Found in 17 different files
#   Example files:
#     - temp_attachments/20250801_071757_631527_20250318 - Firearm audit worksheet - MK - v1.xlsx [List of WV weapons to sell]
#     - temp_attachments/20250801_071756_989524_20250320 - Firearm audit worksheet.xlsx [List of WV weapons to sell]
#     - temp_attachments/20250801_071757_357668_20250319 - Firearm audit worksheet - AMT.xlsx [List of WV weapons to sell]
#     ... and 14 more files
#
# Character '`' (ASCII: 96): example from 20250801_071753_074663_All AUS 3-13-25 1730.xlsx
#   Total occurrences: 159
#   Found in 159 different files
#   Example files:
#     - temp_attachments/20250801_071753_074663_All AUS 3-13-25 1730.xlsx [regionInventoryReport (51)]
#     - temp_attachments/20250801_071755_823310_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     - temp_attachments/20250801_071802_298133_Firearms Reported - Not in A&D Rev. 4-11-25.xlsx [AllAUS]
#     ... and 156 more files
#
# Character '#' (ASCII: 35): example from 20250801_071801_573614_P3 list for AU - company owned.xls
#   Total occurrences: 98
#   Found in 35 different files
#   Example files:
#     - temp_attachments/20250801_071801_573614_P3 list for AU - company owned.xls [Company owned]
#     - temp_attachments/20250801_071753_605565_Orchid Employee Dupes.xlsx [Sheet1]
#     - temp_attachments/20250801_071759_574454_20250318 - Firearm audit worksheet - MK - v1.xlsx [List of all weapons (3-18)]
#     ... and 32 more files
#
# Character "'" (ASCII: 39): example from 20250801_071759_229618_Tiger Team Research Tool v3.xlsx
#   Total occurrences: 96
#   Found in 3 different files
#   Example files:
#     - temp_attachments/20250801_071759_229618_Tiger Team Research Tool v3.xlsx [Mercury Data]
#     - temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [Mercury Data]
#     - temp_attachments/20250801_071801_374510_Tiger Team Research Tool v3.xlsx [Mercury Data]
#
# Character ')' (ASCII: 41): example from 20250801_071801_573614_P3 list for AU - company owned.xls
#   Total occurrences: 95
#   Found in 23 different files
#   Example files:
#     - temp_attachments/20250801_071801_573614_P3 list for AU - company owned.xls [Company owned]
#     - temp_attachments/20250801_071757_816023_2024 Weapon Inventory Breakdown Region_WinTeam Branch (1).xlsx [data]
#     - temp_attachments/20250801_071758_694187_Tiger Team Research Tool v3.xlsx [Mercury Data]
#     ... and 20 more files
